# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

import logging
import math

import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
# sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/')
import datagenerator
from models import MatrixNet
from common import get_logger

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725"

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-09-03 23:27:41,210 - root - INFO - Using device: cuda

# %% [markdown]
# # Settings

# %%
dim = 1
operation = "log"

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]
dim = dim

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-09-03 23:28:51,147 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-09-03 23:28:51,340 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(dim*dim).to(device)
model.load_state_dict(torch.load(models_lst[0]))
logger.info(model)
# Out:
# 2024-09-03 23:28:53,604 - root - INFO - MatrixNet(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(dim*dim).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        logger.info(f"{dim=}")
        for x, y in test_dataset:
            if dim == 1:
                predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                actuals.append(y.view(-1,1).to(device).to(torch.float64))
            else:
                predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                    
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
        mu = np.mean(np.log10(y_is))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-09-03 23:32:29,214 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32.pth
# 2024-09-03 23:32:29,215 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:32:29,253 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:32:29,253 - root - INFO - dim=1
# 2024-09-03 23:32:34,379 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:32:34,380 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:32:34,381 - root - INFO - mu=-1.7195747056340638,sigma=0.5019841042601022
# 2024-09-03 23:32:34,381 - root - INFO - y_main=0.01907327604753364,u_shaded=0.006004007002703573,l_shaded=0.06059117836165212
# 2024-09-03 23:32:34,381 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23
- root - INFO - len(test_dataset)=32768
# 2024-09-03 23:33:11,766 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:33:11,766 - root - INFO - dim=1
# 2024-09-03 23:33:16,930 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:33:16,931 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:33:16,932 - root - INFO - mu=-1.562399181936827,sigma=0.23895375346118305
# 2024-09-03 23:33:16,932 - root - INFO - y_main=0.027390554107313045,u_shaded=0.015799635382562145,l_shaded=0.047484795448740326
# 2024-09-03 23:33:16,932 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:33:16,937 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_16384.pth
# 2024-09-03 23:33:16,937 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:33:16,937 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:33:16,938 - root - INFO - dim=1
# 2024-09-03 23:33:22,278 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:33:22,279 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:33:22,280 - root - INFO - mu=-1.7556232131092704,sigma=0.12317090416760772
# 2024-09-03 23:33:22,280 - root - INFO - y_main=0.017554028005542226,u_shaded=0.013219221593781538,l_shaded=0.023310290778718386
# 2024-09-03 23:33:22,280 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:33:22,287 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32768.pth
# 2024-09-03 23:33:22,287 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:33:22,287 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:33:22,288 - root - INFO - dim=1
# 2024-09-03 23:33:27,455 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:33:27,456 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:33:27,457 - root - INFO - mu=-1.800024167794595,sigma=0.4570677256237483
# 2024-09-03 23:33:27,458 - root - INFO - y_main=0.015848049981390916,u_shaded=0.005532330369159068,l_shaded=0.04539871472839064
# 2024-09-03 23:33:27,458 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:33:27,465 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_65536.pth
# 2024-09-03 23:33:27,465 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:33:27,465 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:33:27,466 - root - INFO - dim=1
# 2024-09-03 23:33:32,808 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:33:32,809 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:33:32,810 - root - INFO - mu=-1.6732720423595921,sigma=0.41183454330721564
# 2024-09-03 23:33:32,810 - root - INFO - y_main=0.021219148766915143,u_shaded=0.008220408778055296,l_shaded=0.054772492043758565
# 2024-09-03 23:33:32,810 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:33:32,816 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_131072.pth
# 2024-09-03 23:33:32,816 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:33:32,817 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:33:32,817 - root - INFO - dim=1
# 2024-09-03 23:33:38,095 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:33:38,096 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:33:38,097 - root - INFO - mu=-2.4355611663867,sigma=0.43781213357098925
# 2024-09-03 23:33:38,098 - root - INFO - y_main=0.0036680802926311266,u_shaded=0.0013385256564990252,l_shaded=0.01005196498689501
# 2024-09-03 23:33:38,098 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:33:38,105 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_262144.pth
# 2024-09-03 23:33:38,105 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:33:38,105 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:33:38,106 - root - INFO - dim=1
# 2024-09-03 23:33:43,528 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:33:43,529 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:33:43,530 - root - INFO - mu=-2.4160228553186593,sigma=0.5553659176908131
# 2024-09-03 23:33:43,531 - root - INFO - y_main=0.003836870529248453,u_shaded=0.0010680983077540557,l_shaded=0.013782977981840552
# 2024-09-03 23:33:43,531 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)

# %%
mu_lst
# Out:
# [-1.7195747056340638,
#  -1.7131813476155044,
#  -1.6428774870367537,
#  -1.5247312428724722,
#  -1.3338144192606871,
#  -1.1662160726574293,
#  -1.1838063117541,
#  -1.1420578992423533,
#  -1.562399181936827,
#  -1.7556232131092704,
#  -1.800024167794595,
#  -1.6732720423595921,
#  -2.4355611663867,
#  -2.4160228553186593]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of log x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples", fontsize=14)
plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title(r"Neural Net Approximation of $log\left(X\right)$ " + f" with dim={dim}", fontsize=18)

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in range(1, -5, -1)])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, f"shaded_plot_dim_{dim}.png"))
# Show the plot


plt.show()

# %% [markdown]
# # Loop

# %%
for dim in range(1, 2):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $log\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Exp_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-03 23:31:05,147 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-03 23:31:05,148 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/test/test_dataset_262144.pt']
# 2024-09-03 23:31:05,162 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_32.pth
# 2024-09-03 23:31:05,163 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:31:05,164 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:31:05,164 - root - INFO - dim=1
# 2024-09-03 23:31:10,597 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:31:10,598 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:31:10,599 - root - INFO - mu=-1.7195747056340638,sigma=0.5019841042601022
# 2024-09-03 23:31:10,599 - root - INFO - y_main=0.01907327604753364,u_shaded=0.006004007002703573,l_shaded=0.06059117836165212
# 2024-09-03 23:31:10,600 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:31:10,604 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_64.pth
# 2024-09-03 23:31:10,604 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:31:10,605 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:31:10,605 - root - INFO - dim=1
# 2024-09-03 23:31:15,928 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:31:15,929 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:31:15,930 - root - INFO - mu=-1.7131813476155044,sigma=0.5211394264020768
# 2024-09-03 23:31:15,930 - root - INFO - y_main=0.019356135442848074,u_shaded=0.005830143253021584,l_shaded=0.06426256834902039
# 2024-09-03 23:31:15,930 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:31:15,935 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_128.pth
# 2024-09-03 23:31:15,935 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:31:15,935 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:31:15,936 - root - INFO - dim=1
# 2024-09-03 23:31:21,404 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:31:21,405 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:31:21,406 - root - INFO - mu=-1.6428774870367537,sigma=0.3313467853708591
# 2024-09-03 23:31:21,406 - root - INFO - y_main=0.022757393183793547,u_shaded=0.010611474324613247,l_shaded=0.048805559781689316
# 2024-09-03 23:31:21,407 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:31:21,413 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_1/log_model_256.pth
# 2024-09-03 23:31:21,414 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:31:21,414 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:31:21,414 - root - INFO - dim=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 44
#      42 for x, y in test_dataset:
#      43     if dim == 1:
# ---> 44         predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
#      45         actuals.append(y.view(-1,1).to(device).to(torch.float64))
#      46     else:
#
# File ~/Development/envs/venv310/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Development/envs/venv310/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Development/ws1/masters_thesis_2/LAWT/src/neuralnet/models.py:16, in MatrixNet.forward(self, x)
#      14 x = self.relu(self.fc1(x))
#      15 x = self.relu(self.fc2(x))
# ---> 16 x = self.relu(self.fc3(x))
#      17 x = self.fc4(x)
#      18 return x
#
# File ~/Development/envs/venv310/lib/python3.10/site-packages/torch/nn/modules/module.py:1508, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1507 def _wrapped_call_impl(self, *args, **kwargs):
# -> 1508     if self._compiled_call_impl is not None:
#    1509         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510     else:
#
# KeyboardInterrupt:

# %%
for dim in range(2, 11):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $log\left(X\right)$ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Log_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-03 23:37:33,649 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-03 23:37:33,650 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/test/test_dataset_262144.pt']
# 2024-09-03 23:37:33,662 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_32.pth
# 2024-09-03 23:37:33,663 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:37:33,694 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:37:33,694 - root - INFO - dim=2
# 2024-09-03 23:37:38,510 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 23:37:38,511 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:37:38,514 - root - INFO - mu=-0.40246185746993945,sigma=0.3975210405957348
# 2024-09-03 23:37:38,514 - root - INFO - y_main=0.39585682999770744,u_shaded=0.15849556046586002,l_shaded=0.9886878181019313
# 2024-09-03 23:37:38,514 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 23:37:38,519 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_64.pth
# 2024-09-03 23:37:38,520 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:37:38,520 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:37:38,520 - root - INFO - dim=2
# 2024-09-03 23:37:43,481 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 23:37:43,482 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:37:43,484 - root - INFO - mu=-0.6106737458385745,sigma=0.33910173115386133
# 2024-09-03 23:37:43,485 - root - INFO - y_main=0.24509037378784446,u_shaded=0.11225986691068403,l_shaded=0.5350914175878859
# 2024-09-03 23:37:43,485 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 23:37:43,490 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_128.pth
# 2024-09-03 23:37:43,490 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:37:43,490 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:37:43,491 - root - INFO - dim=2
# 2024-09-03 23:37:48,293 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 23:37:48,294 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:37:48,297 - root - INFO - mu=-0.5947687980321403,sigma=0.3185589435007042
# 2024-09-03 23:37:48,297 - root - INFO - y_main=0.2542325783512651,u_shaded=0.12208779734899722,l_shaded=0.5294075681484399
# 2024-09-03 23:37:48,297 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 23:37:48,302 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_2/log_model_256.pth
# 2024-09-03 23:37:48,303 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:37:48,303 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:37:48,304 - root - INFO - dim=2
# 2024-09-03 23:37:53,299 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 23:37:53,300 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:37:53,303 - root - INFO - mu=-0.7413269705573551,sigma=0.34952946827901743
# 2024-09-03 23:37:53,303 - root - INFO - y_main=0.18141493162334116,u_shaded=0.08112291749092305,l_shaded=0.405697655284452
# 2024-09-03 23:37:53,303 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 23
- root - INFO - len(test_dataset)=32768
# 2024-09-03 23:40:57,947 - root - INFO - Starting to predict values in the test_dataset
# ...
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/test/test_dataset_262144.pt']
# 2024-09-03 23:47:11,904 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_32.pth
# 2024-09-03 23:47:11,904 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:11,905 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:11,905 - root - INFO - dim=10
# 2024-09-03 23:47:16,930 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:16,940 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:17,003 - root - INFO - mu=0.041553342813235236,sigma=0.2888084814722824
# 2024-09-03 23:47:17,003 - root - INFO - y_main=1.1004069959886007,u_shaded=0.5659067333396159,l_shaded=2.1397440346304646
# 2024-09-03 23:47:17,005 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:17,073 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_64.pth
# 2024-09-03 23:47:17,073 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:17,074 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:17,074 - root - INFO - dim=10
# 2024-09-03 23:47:22,354 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:22,361 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:22,425 - root - INFO - mu=0.07085580531407651,sigma=0.2908258713711346
# 2024-09-03 23:47:22,425 - root - INFO - y_main=1.1772150490573543,u_shaded=0.6026011191967855,l_shaded=2.2997555556722262
# 2024-09-03 23:47:22,427 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:22,495 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_128.pth
# 2024-09-03 23:47:22,496 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:22,496 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:22,496 - root - INFO - dim=10
# 2024-09-03 23:47:27,596 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:27,603 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:27,668 - root - INFO - mu=0.024217658420006602,sigma=0.2707215011687516
# 2024-09-03 23:47:27,668 - root - INFO - y_main=1.057347294624687,u_shaded=0.5668865555436454,l_shaded=1.9721464383257357
# 2024-09-03 23:47:27,670 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:27,741 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_256.pth
# 2024-09-03 23:47:27,741 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:27,741 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:27,742 - root - INFO - dim=10
# 2024-09-03 23:47:32,956 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:32,963 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:33,024 - root - INFO - mu=0.016368711730107198,sigma=0.25887147202480143
# 2024-09-03 23:47:33,024 - root - INFO - y_main=1.038409641229028,u_shaded=0.5721333182681508,l_shaded=1.884691117555257
# 2024-09-03 23:47:33,027 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:33,093 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_512.pth
# 2024-09-03 23:47:33,094 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:33,094 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:33,095 - root - INFO - dim=10
# 2024-09-03 23:47:37,994 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:38,001 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:38,063 - root - INFO - mu=0.005246803735221323,sigma=0.25152740240286053
# 2024-09-03 23:47:38,064 - root - INFO - y_main=1.0121544846857922,u_shaded=0.5671780319631342,l_shaded=1.8062348030717623
# 2024-09-03 23:47:38,066 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:38,105 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_1024.pth
# 2024-09-03 23:47:38,105 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:38,106 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:38,106 - root - INFO - dim=10
# 2024-09-03 23:47:43,136 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:43,142 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:43,202 - root - INFO - mu=0.007701077680683122,sigma=0.2936638212439653
# 2024-09-03 23:47:43,203 - root - INFO - y_main=1.0178905388582684,u_shaded=0.5176512373348501,l_shaded=2.0015428813260217
# 2024-09-03 23:47:43,204 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:43,277 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_2048.pth
# 2024-09-03 23:47:43,278 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:43,279 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:43,279 - root - INFO - dim=10
# 2024-09-03 23:47:48,316 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:48,323 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:48,384 - root - INFO - mu=0.003814660373663812,sigma=0.30208272581565493
# 2024-09-03 23:47:48,384 - root - INFO - y_main=1.0088222689435424,u_shaded=0.5031899222090774,l_shaded=2.0225412421783937
# 2024-09-03 23:47:48,386 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:48,459 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_4096.pth
# 2024-09-03 23:47:48,460 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:48,460 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:48,461 - root - INFO - dim=10
# 2024-09-03 23:47:53,328 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:53,335 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:53,396 - root - INFO - mu=-0.019116462660738055,sigma=0.2893934863769057
# 2024-09-03 23:47:53,397 - root - INFO - y_main=0.9569374195822585,u_shaded=0.49146212140746415,l_shaded=1.8632752863521982
# 2024-09-03 23:47:53,399 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:53,476 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_8192.pth
# 2024-09-03 23:47:53,476 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:53,477 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:53,477 - root - INFO - dim=10
# 2024-09-03 23:47:58,475 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:47:58,492 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:47:58,554 - root - INFO - mu=-0.006356011715748332,sigma=0.32052626754096214
# 2024-09-03 23:47:58,555 - root - INFO - y_main=0.9854713170080562,u_shaded=0.47110500777049125,l_shaded=2.061437897341798
# 2024-09-03 23:47:58,556 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:47:58,608 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_16384.pth
# 2024-09-03 23:47:58,609 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:47:58,609 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:47:58,609 - root - INFO - dim=10
# 2024-09-03 23:48:03,567 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:48:03,574 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:48:03,637 - root - INFO - mu=-0.022400842468930753,sigma=0.31011065259635284
# 2024-09-03 23:48:03,638 - root - INFO - y_main=0.9497278150250544,u_shaded=0.46503806720595753,l_shaded=1.9395894363047725
# 2024-09-03 23:48:03,639 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:48:03,784 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_32768.pth
# 2024-09-03 23:48:03,784 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:48:03,785 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:48:03,785 - root - INFO - dim=10
# 2024-09-03 23:48:08,692 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:48:08,699 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:48:08,760 - root - INFO - mu=-0.044899966542736675,sigma=0.3112997342748749
# 2024-09-03 23:48:08,760 - root - INFO - y_main=0.9017788254055665,u_shaded=0.4403523305581447,l_shaded=1.846714536333007
# 2024-09-03 23:48:08,763 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:48:08,997 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_65536.pth
# 2024-09-03 23:48:08,998 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:48:08,998 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:48:08,998 - root - INFO - dim=10
# 2024-09-03 23:48:14,183 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:48:14,189 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:48:14,253 - root - INFO - mu=-0.06206366541022261,sigma=0.30389459757503173
# 2024-09-03 23:48:14,254 - root - INFO - y_main=0.8668347927758778,u_shaded=0.4305679873907954,l_shaded=1.745142648714395
# 2024-09-03 23:48:14,255 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:48:14,568 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_131072.pth
# 2024-09-03 23:48:14,569 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:48:14,569 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:48:14,570 - root - INFO - dim=10
# 2024-09-03 23:48:19,506 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:48:19,513 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:48:19,573 - root - INFO - mu=-0.06740930904913968,sigma=0.2964767324964389
# 2024-09-03 23:48:19,573 - root - INFO - y_main=0.8562304942136605,u_shaded=0.4326273371396497,l_shaded=1.6946008638023693
# 2024-09-03 23:48:19,575 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 23:48:20,208 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/log/20240903000725/dim_10/log_model_262144.pth
# 2024-09-03 23:48:20,209 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:48:20,209 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:48:20,210 - root - INFO - dim=10
# 2024-09-03 23:48:25,429 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 23:48:25,435 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:48:25,497 - root - INFO - mu=-0.0766829391179821,sigma=0.3016932621006301
# 2024-09-03 23:48:25,497 - root - INFO - y_main=0.8381409517207362,u_shaded=0.4184309484192563,l_shaded=1.6788439230060863
# 2024-09-03 23:48:25,499 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)

# %%
mu
# Out:
# -0.20268292184499373
