# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

import logging
import math

import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
# sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/')
import datagenerator
from models import MatrixNet
from common import get_logger
# Out:
# 2024-09-04 00:26:45,680 - datagenerator - INFO - Using device: cuda

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111"

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-09-04 00:26:47,135 - root - INFO - Using device: cuda

# %% [markdown]
# # Settings

# %%
dim = 1
operation = "sin"

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]
dim = dim

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-09-04 00:26:59,408 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-09-04 00:27:01,314 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/test/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(dim*dim).to(device)
model.load_state_dict(torch.load(models_lst[0]))
logger.info(model)
# Out:
# 2024-09-04 00:27:05,297 - root - INFO - MatrixNet(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(dim*dim).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        logger.info(f"{dim=}")
        for x, y in test_dataset:
            if dim == 1:
                predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                actuals.append(y.view(-1,1).to(device).to(torch.float64))
            else:
                predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                    
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
        mu = np.mean(np.log10(y_is))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-09-04 00:27:06,297 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_32.pth
# 2024-09-04 00:27:06,298 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:27:06,298 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:27:06,298 - root - INFO - dim=1
# 2024-09-04 00:27:11,521 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:27:11,522 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:27
- root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:27:48,707 - root - INFO - dim=1
# 2024-09-04 00:27:53,944 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:27:53,945 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:27:53,946 - root - INFO - mu=-3.204348942658301,sigma=0.42099531970668314
# 2024-09-04 00:27:53,947 - root - INFO - y_main=0.0006246705869106744,u_shaded=0.00023694946782453882,l_shaded=0.0016468209265626185
# 2024-09-04 00:27:53,947 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:27:53,955 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_16384.pth
# 2024-09-04 00:27:53,955 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:27:53,956 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:27:53,956 - root - INFO - dim=1
# 2024-09-04 00:27:59,285 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:27:59,286 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:27:59,287 - root - INFO - mu=-2.495007608686837,sigma=0.23726898519710946
# 2024-09-04 00:27:59,287 - root - INFO - y_main=0.003198839066663174,u_shaded=0.0018523515202587438,l_shaded=0.005524098024861501
# 2024-09-04 00:27:59,287 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:27:59,296 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_32768.pth
# 2024-09-04 00:27:59,296 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:27:59,297 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:27:59,297 - root - INFO - dim=1
# 2024-09-04 00:28:04,537 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:28:04,538 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:28:04,539 - root - INFO - mu=-3.399391930191923,sigma=0.2917256119086212
# 2024-09-04 00:28:04,539 - root - INFO - y_main=0.00039866496373279855,u_shaded=0.00020364908254666227,l_shaded=0.0007804295080566198
# 2024-09-04 00:28:04,539 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:28:04,547 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_65536.pth
# 2024-09-04 00:28:04,548 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:28:04,548 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:28:04,548 - root - INFO - dim=1
# 2024-09-04 00:28:09,869 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:28:09,870 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:28:09,871 - root - INFO - mu=-2.6091592697540458,sigma=0.098320396257949
# 2024-09-04 00:28:09,871 - root - INFO - y_main=0.002459465473648489,u_shaded=0.0019611929978292923,l_shaded=0.003084332048280904
# 2024-09-04 00:28:09,871 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:28:09,881 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_131072.pth
# 2024-09-04 00:28:09,882 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:28:09,882 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:28:09,882 - root - INFO - dim=1
# 2024-09-04 00:28:15,216 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:28:15,217 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:28:15,218 - root - INFO - mu=-3.556772443005844,sigma=0.32770505953084617
# 2024-09-04 00:28:15,218 - root - INFO - y_main=0.0002774773620129276,u_shaded=0.00013047355552228156,l_shaded=0.0005901095139275538
# 2024-09-04 00:28:15,218 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:28:15,230 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_1/sin_model_262144.pth
# 2024-09-04 00:28:15,230 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:28:15,230 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:28:15,231 - root - INFO - dim=1
# 2024-09-04 00:28:20,300 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:28:20,301 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:28:20,302 - root - INFO - mu=-2.1594809749110064,sigma=0.14196685969744122
# 2024-09-04 00:28:20,302 - root - INFO - y_main=0.006926582719749242,u_shaded=0.004995191764771829,l_shaded=0.00960474601033066
# 2024-09-04 00:28:20,302 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)

# %%
mu_lst
# Out:
# [-2.4097000365951455,
#  -2.2591936689659162,
#  -2.5553183508512687,
#  -3.1529672461718454,
#  -3.3338724045995365,
#  -2.7751656295046523,
#  -2.666067995825529,
#  -2.2794182451754734,
#  -3.204348942658301,
#  -2.495007608686837,
#  -3.399391930191923,
#  -2.6091592697540458,
#  -3.556772443005844,
#  -2.1594809749110064]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of sin x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples", fontsize=14)
plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title(r"Neural Net Approximation of $\text{sin}\left(X\right)$ " + f" with dim={dim}", fontsize=18)

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in range(1, -5, -1)])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, f"shaded_plot_dim_{dim}.png"))
# Show the plot


plt.show()

# %% [markdown]
# # Loop

# %%
for dim in range(1, 2):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $log\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Exp_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot

# %%
for dim in range(2, 11):
    
    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/(np.abs(np_actuals) + 1e-5)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $\text{sin}\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Sine_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-04 00:29:53,993 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00
- root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00:30:57,525 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/test/test_dataset_262144.pt']
# 2024-09-04 00:30:57,535 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_32.pth
# 2024-09-04 00:30:57,536 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:30:57,536 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:30:57,537 - root - INFO - dim=3
# 2024-09-04 00:31:02,065 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:02,069 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:02,075 - root - INFO - mu=-0.644782685124506,sigma=0.3733900550025289
# 2024-09-04 00:31:02,075 - root - INFO - y_main=0.22657777874483206,u_shaded=0.09590191069067554,l_shaded=0.5353124817974412
# 2024-09-04 00:31:02,076 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:02,092 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_64.pth
# 2024-09-04 00:31:02,092 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:02,093 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:02,093 - root - INFO - dim=3
# 2024-09-04 00:31:06,728 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:06,730 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:06,736 - root - INFO - mu=-0.7545105456066077,sigma=0.3882337840959909
# 2024-09-04 00:31:06,736 - root - INFO - y_main=0.1759905928971307,u_shaded=0.0719872644193243,l_shaded=0.4302523375227642
# 2024-09-04 00:31:06,737 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:06,748 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_128.pth
# 2024-09-04 00:31:06,749 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:06,749 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:06,749 - root - INFO - dim=3
# 2024-09-04 00:31:11,186 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:11,188 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:11,194 - root - INFO - mu=-0.8092586494900602,sigma=0.39616586997377606
# 2024-09-04 00:31:11,194 - root - INFO - y_main=0.15514627417884003,u_shaded=0.06231254374420913,l_shaded=0.3862844452376048
# 2024-09-04 00:31:11,195 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:11,207 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_256.pth
# 2024-09-04 00:31:11,207 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:11,208 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:11,208 - root - INFO - dim=3
# 2024-09-04 00:31:15,772 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:15,773 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:15,778 - root - INFO - mu=-0.9211741448786265,sigma=0.40076196067166964
# 2024-09-04 00:31:15,778 - root - INFO - y_main=0.11990184202581214,u_shaded=0.04765010856355887,l_shaded=0.3017086876519189
# 2024-09-04 00:31:15,779 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:15,791 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_512.pth
# 2024-09-04 00:31:15,791 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:15,792 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:15,792 - root - INFO - dim=3
# 2024-09-04 00:31:20,507 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:20,509 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:20,514 - root - INFO - mu=-1.0798191443759828,sigma=0.4034502609991199
# 2024-09-04 00:31:20,515 - root - INFO - y_main=0.08321102191661238,u_shaded=0.03286476979974573,l_shaded=0.21068378724686876
# 2024-09-04 00:31:20,515 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:20,527 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_1024.pth
# 2024-09-04 00:31:20,528 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:20,528 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:20,529 - root - INFO - dim=3
# 2024-09-04 00:31:25,351 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:25,353 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:25,358 - root - INFO - mu=-1.1936483397275042,sigma=0.4045727153142109
# 2024-09-04 00:31:25,358 - root - INFO - y_main=0.06402530562809444,u_shaded=0.02522196652538848,l_shaded=0.1625265720912205
# 2024-09-04 00:31:25,358 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:25,370 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_2048.pth
# 2024-09-04 00:31:25,371 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:25,371 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:25,371 - root - INFO - dim=3
# 2024-09-04 00:31:29,907 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:29,908 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:29,913 - root - INFO - mu=-1.2222005764723267,sigma=0.4078765924941215
# 2024-09-04 00:31:29,913 - root - INFO - y_main=0.05995141300666042,u_shaded=0.023438123107331878,l_shaded=0.1533472584402822
# 2024-09-04 00:31:29,914 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:29,925 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_4096.pth
# 2024-09-04 00:31:29,926 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:29,926 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:29,926 - root - INFO - dim=3
# 2024-09-04 00:31:34,390 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:34,392 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:34,397 - root - INFO - mu=-1.3420153784155096,sigma=0.4083179999528498
# 2024-09-04 00:31:34,397 - root - INFO - y_main=0.04549719492578966,u_shaded=0.017769148695493283,l_shaded=0.11649374888963054
# 2024-09-04 00:31:34,397 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:34,409 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_8192.pth
# 2024-09-04 00:31:34,409 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:34,410 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:34,410 - root - INFO - dim=3
# 2024-09-04 00:31:39,248 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:39,250 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:39,255 - root - INFO - mu=-1.4717745099022022,sigma=0.41301737689396795
# 2024-09-04 00:31:39,256 - root - INFO - y_main=0.03374624771195634,u_shaded=0.013037914034840677,l_shaded=0.08734596896355705
# 2024-09-04 00:31:39,256 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:39,270 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_16384.pth
# 2024-09-04 00:31:39,270 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:39,271 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:39,271 - root - INFO - dim=3
# 2024-09-04 00:31:44,084 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:44,085 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:44,093 - root - INFO - mu=-1.625526379477389,sigma=0.4101577660533438
# 2024-09-04 00:31:44,093 - root - INFO - y_main=0.02368501262299999,u_shaded=0.009211192414573858,l_shaded=0.060901976389516284
# 2024-09-04 00:31:44,093 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:44,108 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_32768.pth
# 2024-09-04 00:31:44,109 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:44,109 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:44,109 - root - INFO - dim=3
# 2024-09-04 00:31:48,909 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:48,911 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:48,916 - root - INFO - mu=-1.6994575508525323,sigma=0.40977699534503764
# 2024-09-04 00:31:48,917 - root - INFO - y_main=0.019977560251160965,u_shaded=0.007776164760577596,l_shaded=0.05132387569924924
# 2024-09-04 00:31:48,917 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:48,939 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_65536.pth
# 2024-09-04 00:31:48,939 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:48,940 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:48,940 - root - INFO - dim=3
# 2024-09-04 00:31:54,090 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:54,091 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:54,097 - root - INFO - mu=-1.7386335749297719,sigma=0.4130006215954208
# 2024-09-04 00:31:54,098 - root - INFO - y_main=0.01825435217919223,u_shaded=0.007052868774943363,l_shaded=0.047246217690283906
# 2024-09-04 00:31:54,098 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:54,128 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_131072.pth
# 2024-09-04 00:31:54,128 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:54,129 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:54,129 - root - INFO - dim=3
# 2024-09-04 00:31:59,043 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:31:59,045 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:31:59,050 - root - INFO - mu=-1.799227900329394,sigma=0.41090504166896685
# 2024-09-04 00:31:59,050 - root - INFO - y_main=0.015877133616461623,u_shaded=0.006164062846884972,l_shaded=0.0408956524514293
# 2024-09-04 00:31:59,050 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:31:59,106 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_3/sin_model_262144.pth
# 2024-09-04 00:31:59,107 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:31:59,110 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:31:59,110 - root - INFO - dim=3
# 2024-09-04 00:32:03,763 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:32:03,764 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:32:03,769 - root - INFO - mu=-1.835434354749643,sigma=0.41050144906149477
# 2024-09-04 00:32:03,770 - root - INFO - y_main=0.0146071552542137,u_shaded=0.005676285044566078,l_shaded=0.03758954720305344
# 2024-09-04 00:32:03,770 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:32:04,075 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00:32:04,076 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model
- root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:32:36,887 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model_4096.pth
# 2024-09-04 00:32:36,888 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:32:36,889 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:32:36,889 - root - INFO - dim=4
# 2024-09-04 00:32:41,464 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:32:41,466 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:32:41,475 - root - INFO - mu=-0.9515318875637332,sigma=0.4123763967260631
# 2024-09-04 00:32:41,475 - root - INFO - y_main=0.11180677287567418,u_shaded=0.04326051803469975,l_shaded=0.28896451149395846
# 2024-09-04 00:32:41,476 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:32:41,490 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model_8192.pth
# 2024-09-04 00:32:41,490 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:32:41,491 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:32:41,491 - root - INFO - dim=4
# 2024-09-04 00:32:45,962 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:32:45,964 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:32:45,973 - root - INFO - mu=-1.0419613166829818,sigma=0.41616034299872345
# 2024-09-04 00:32:45,973 - root - INFO - y_main=0.09079013948330715,u_shaded=0.0348239748353965,l_shaded=0.23670041878792078
# 2024-09-04 00:32:45,973 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:32:45,987 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model_16384.pth
# 2024-09-04 00:32:45,988 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:32:45,988 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:32:45,989 - root - INFO - dim=4
# 2024-09-04 00:32:50,875 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:32:50,876 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:32:50,885 - root - INFO - mu=-1.1133363579915407,sigma=0.4164665205112936
# 2024-09-04 00:32:50,885 - root - INFO - y_main=0.0770306640952589,u_shaded=0.029525490521757382,l_shaded=0.20096950486170714
# 2024-09-04 00:32:50,886 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:32:50,910 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model_32768.pth
# 2024-09-04 00:32:50,910 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:32:50,911 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:32:50,911 - root - INFO - dim=4
# 2024-09-04 00:32:55,702 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:32:55,704 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:32:55,713 - root - INFO - mu=-1.1974681174955772,sigma=0.4144656672163531
# 2024-09-04 00:32:55,713 - root - INFO - y_main=0.06346464900531537,u_shaded=0.024438031219971647,l_shaded=0.1648153092658399
# 2024-09-04 00:32:55,713 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:32:55,741 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model_65536.pth
# 2024-09-04 00:32:55,742 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:32:55,742 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:32:55,742 - root - INFO - dim=4
# 2024-09-04 00:33:00,405 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:33:00,407 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:33:00,416 - root - INFO - mu=-1.2781841916145036,sigma=0.41950138050915275
# 2024-09-04 00:33:00,416 - root - INFO - y_main=0.052700630175749774,u_shaded=0.02005923784451505,l_shaded=0.13845772418918606
# 2024-09-04 00:33:00,417 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:33:00,456 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_4/sin_model_131072.pth
# 2024-09-04 00:33:00,457 - root - INFO - len(test_dataset)=32768
# ...
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/test/test_dataset_262144.pt']
# 2024-09-04 00:38:41,295 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_32.pth
# 2024-09-04 00:38:41,295 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:38:41,296 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:38:41,296 - root - INFO - dim=10
# 2024-09-04 00:38:46,188 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:38:46,218 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:38:46,285 - root - INFO - mu=-0.03699637383929366,sigma=0.19924748430961975
# 2024-09-04 00:38:46,286 - root - INFO - y_main=0.9183402641736336,u_shaded=0.5804384074339565,l_shaded=1.4529514759900812
# 2024-09-04 00:38:46,287 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:38:46,324 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_64.pth
# 2024-09-04 00:38:46,325 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:38:46,325 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:38:46,325 - root - INFO - dim=10
# 2024-09-04 00:38:51,372 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:38:51,379 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:38:51,447 - root - INFO - mu=-0.05824384181036349,sigma=0.2513566723877246
# 2024-09-04 00:38:51,447 - root - INFO - y_main=0.8744926390253788,u_shaded=0.49022954971146343,l_shaded=1.559957730331997
# 2024-09-04 00:38:51,449 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:38:51,487 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_128.pth
# 2024-09-04 00:38:51,487 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:38:51,488 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:38:51,488 - root - INFO - dim=10
# 2024-09-04 00:38:56,159 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:38:56,166 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:38:56,231 - root - INFO - mu=-0.08198761962140956,sigma=0.3094723113427307
# 2024-09-04 00:38:56,231 - root - INFO - y_main=0.8279657660926715,u_shaded=0.4060131212542103,l_shaded=1.6884363433964158
# 2024-09-04 00:38:56,233 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:38:56,270 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_256.pth
# 2024-09-04 00:38:56,271 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:38:56,271 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:38:56,272 - root - INFO - dim=10
# 2024-09-04 00:39:01,000 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:01,007 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:01,067 - root - INFO - mu=-0.11031300840182783,sigma=0.34724532875551317
# 2024-09-04 00:39:01,068 - root - INFO - y_main=0.7756878547863736,u_shaded=0.34869174252850316,l_shaded=1.7255689615704104
# 2024-09-04 00:39:01,070 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:01,114 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_512.pth
# 2024-09-04 00:39:01,115 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:01,115 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:01,115 - root - INFO - dim=10
# 2024-09-04 00:39:05,726 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:05,732 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:05,799 - root - INFO - mu=-0.14388729569473205,sigma=0.3746396705520593
# 2024-09-04 00:39:05,800 - root - INFO - y_main=0.7179805911398588,u_shaded=0.3030212139778701,l_shaded=1.701188251761107
# 2024-09-04 00:39:05,802 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:05,842 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_1024.pth
# 2024-09-04 00:39:05,842 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:05,843 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:05,843 - root - INFO - dim=10
# 2024-09-04 00:39:10,516 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:10,523 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:10,587 - root - INFO - mu=-0.20155944426406008,sigma=0.39257387528167476
# 2024-09-04 00:39:10,588 - root - INFO - y_main=0.6286957951920946,u_shaded=0.25460485476462386,l_shaded=1.5524385945335855
# 2024-09-04 00:39:10,590 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:10,626 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_2048.pth
# 2024-09-04 00:39:10,627 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:10,627 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:10,627 - root - INFO - dim=10
# 2024-09-04 00:39:15,469 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:15,475 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:15,538 - root - INFO - mu=-0.2683518412665521,sigma=0.40480935492282416
# 2024-09-04 00:39:15,539 - root - INFO - y_main=0.5390737179774243,u_shaded=0.21224565279583735,l_shaded=1.3691704380562135
# 2024-09-04 00:39:15,540 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:15,599 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_4096.pth
# 2024-09-04 00:39:15,600 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:15,600 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:15,600 - root - INFO - dim=10
# 2024-09-04 00:39:20,417 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:20,423 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:20,483 - root - INFO - mu=-0.30797864603190744,sigma=0.4102408231705278
# 2024-09-04 00:39:20,484 - root - INFO - y_main=0.4920637295298608,u_shaded=0.19132888068481463,l_shaded=1.2655000805534586
# 2024-09-04 00:39:20,485 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:20,528 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_8192.pth
# 2024-09-04 00:39:20,528 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:20,528 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:20,529 - root - INFO - dim=10
# 2024-09-04 00:39:25,149 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:25,156 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:25,217 - root - INFO - mu=-0.32473323593629666,sigma=0.41505923085444524
# 2024-09-04 00:39:25,218 - root - INFO - y_main=0.4734419799603321,u_shaded=0.1820570633892095,l_shaded=1.2311925954203036
# 2024-09-04 00:39:25,220 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:25,278 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_16384.pth
# 2024-09-04 00:39:25,279 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:25,279 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:25,280 - root - INFO - dim=10
# 2024-09-04 00:39:29,814 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:29,822 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:29,884 - root - INFO - mu=-0.33119494230442137,sigma=0.41619789796359336
# 2024-09-04 00:39:29,884 - root - INFO - y_main=0.46644995734314165,u_shaded=0.17889868971541042,l_shaded=1.216194277618997
# 2024-09-04 00:39:29,886 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:29,967 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_32768.pth
# 2024-09-04 00:39:29,968 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:29,968 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:29,969 - root - INFO - dim=10
# 2024-09-04 00:39:34,976 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:34,983 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:35,073 - root - INFO - mu=-0.3312002037910569,sigma=0.41709341666238087
# 2024-09-04 00:39:35,073 - root - INFO - y_main=0.4664443063264869,u_shaded=0.17852801636751722,l_shaded=1.2186899027461775
# 2024-09-04 00:39:35,075 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:35,212 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_65536.pth
# 2024-09-04 00:39:35,212 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:35,213 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:35,213 - root - INFO - dim=10
# 2024-09-04 00:39:39,932 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:39,940 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:40,002 - root - INFO - mu=-0.3340748770269649,sigma=0.41760570935369806
# 2024-09-04 00:39:40,003 - root - INFO - y_main=0.463367023404039,u_shaded=0.17714113116784924,l_shaded=1.2120787361060303
# 2024-09-04 00:39:40,012 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:40,266 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_131072.pth
# 2024-09-04 00:39:40,267 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:40,267 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:40,268 - root - INFO - dim=10
# 2024-09-04 00:39:45,474 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:45,502 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:45,565 - root - INFO - mu=-0.337541624957669,sigma=0.4160129116258666
# 2024-09-04 00:39:45,566 - root - INFO - y_main=0.4596829281059464,u_shaded=0.17637842631411432,l_shaded=1.1980399122948018
# 2024-09-04 00:39:45,567 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:39:45,979 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sin/20240903170111/dim_10/sin_model_262144.pth
# 2024-09-04 00:39:45,980 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:39:45,980 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:39:45,981 - root - INFO - dim=10
# 2024-09-04 00:39:50,727 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:39:50,734 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:39:50,797 - root - INFO - mu=-0.34322740496879617,sigma=0.4181275054403604
# 2024-09-04 00:39:50,798 - root - INFO - y_main=0.45370398628198816,u_shaded=0.17323876921209025,l_shaded=1.188228871079976
# 2024-09-04 00:39:50,800 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
