# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

import logging
import math

import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
# sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/')
import datagenerator
from models import MatrixNet
from common import get_logger

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914"

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-09-03 23:52:23,946 - root - INFO - Using device: cuda

# %% [markdown]
# # Settings

# %%
dim = 1
operation = "sign"

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]
dim = dim

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-09-03 23:52:26,708 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-09-03 23:52:29,556 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/test/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(dim*dim).to(device)
model.load_state_dict(torch.load(models_lst[0]))
logger.info(model)
# Out:
# 2024-09-03 23:52:31,702 - root - INFO - MatrixNet(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(dim*dim).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        logger.info(f"{dim=}")
        for x, y in test_dataset:
            if dim == 1:
                predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                actuals.append(y.view(-1,1).to(device).to(torch.float64))
            else:
                predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                    
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
        mu = np.mean(np.log10(y_is))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-09-03 23:52:32,506 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_32.pth
# 2024-09-03 23:52:32,507 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:52:32,507 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:52:32,507 - root - INFO - dim=1
# 2024-09-03 23:52:37,622 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:52:37,622 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:52:37,623 - root - INFO - mu=-1.510514105621827,sigma=0.3203965978041136
# 2024-09-03 23:52:37,624 - root - INFO - y_main=0.030866393918771464,u_shaded=0.01476009988860844,l_shaded=0.0645479556872155
# 2024-09-03 23:52:37,624 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23
- root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:53:18,378 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:53:18,379 - root - INFO - mu=-2.6336124167798873,sigma=0.2295478069431019
# 2024-09-03 23:53:18,380 - root - INFO - y_main=0.002324810632606067,u_shaded=0.0013703761017429122,l_shaded=0.003943986231666036
# 2024-09-03 23:53:18,380 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:53:18,387 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_16384.pth
# 2024-09-03 23:53:18,387 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:53:18,388 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:53:18,388 - root - INFO - dim=1
# 2024-09-03 23:53:23,577 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:53:23,579 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:53:23,580 - root - INFO - mu=-2.61871372045653,sigma=0.2625526166140362
# 2024-09-03 23:53:23,580 - root - INFO - y_main=0.0024059482376020593,u_shaded=0.0013144184997278723,l_shaded=0.004403914676504388
# 2024-09-03 23:53:23,580 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:53:23,588 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_32768.pth
# 2024-09-03 23:53:23,588 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:53:23,589 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:53:23,589 - root - INFO - dim=1
# 2024-09-03 23:53:28,529 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:53:28,530 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:53:28,531 - root - INFO - mu=-2.1953192891672004,sigma=0.17732744938895614
# 2024-09-03 23:53:28,531 - root - INFO - y_main=0.006377944134038948,u_shaded=0.00423987703583827,l_shaded=0.009594186584441668
# 2024-09-03 23:53:28,532 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:53:28,539 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_65536.pth
# 2024-09-03 23:53:28,540 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:53:28,540 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:53:28,541 - root - INFO - dim=1
# 2024-09-03 23:53:33,797 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:53:33,797 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:53:33,798 - root - INFO - mu=-2.842393309069752,sigma=0.13807870604884728
# 2024-09-03 23:53:33,799 - root - INFO - y_main=0.0014374961523965888,u_shaded=0.0010459910894164536,l_shaded=0.0019755380414452814
# 2024-09-03 23:53:33,799 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:53:33,809 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_131072.pth
# 2024-09-03 23:53:33,809 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:53:33,810 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:53:33,810 - root - INFO - dim=1
# 2024-09-03 23:53:39,012 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:53:39,013 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:53:39,014 - root - INFO - mu=-2.4067071458407234,sigma=0.0071291522112214584
# 2024-09-03 23:53:39,014 - root - INFO - y_main=0.003920061262100204,u_shaded=0.0038562368636613845,l_shaded=0.003984942015213308
# 2024-09-03 23:53:39,015 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 23:53:39,028 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_1/sign_model_262144.pth
# 2024-09-03 23:53:39,029 - root - INFO - len(test_dataset)=32768
# 2024-09-03 23:53:39,029 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 23:53:39,029 - root - INFO - dim=1
# 2024-09-03 23:53:44,102 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 23:53:44,103 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 23:53:44,104 - root - INFO - mu=-4.508025940972254,sigma=0.1271536143481246
# 2024-09-03 23:53:44,104 - root - INFO - y_main=3.104374154298775e-05,u_shaded=2.3164367411038483e-05,l_shaded=4.1603289737521e-05
# 2024-09-03 23:53:44,104 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)

# %%
mu_lst
# Out:
# [-1.510514105621827,
#  -1.3395266270815585,
#  -1.6133240582829518,
#  -2.158140125939002,
#  -2.29651641528151,
#  -1.7650615840728905,
#  -2.3504395062219814,
#  -2.0602971709461184,
#  -2.6336124167798873,
#  -2.61871372045653,
#  -2.1953192891672004,
#  -2.842393309069752,
#  -2.4067071458407234,
#  -4.508025940972254]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of sign x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples", fontsize=14)
plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title(r"Neural Net Approximation of $\text{sign}\left(X\right)$ " + f" with dim={dim}", fontsize=18)

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in range(1, -5, -1)])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, f"shaded_plot_dim_{dim}.png"))
# Show the plot


plt.show()

# %% [markdown]
# # Loop

# %%
for dim in range(1, 2):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $log\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Exp_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot

# %%
for dim in range(2, 11):
    
    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/(np.abs(np_actuals) + 1e-5)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $\text{sign}\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(4, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Sign_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-04 00:12:48,600 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00:12:48,601 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/test/test_dataset_262144.pt']
# 2024-09-04 00:12:48,610 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_32.pth
# 2024-09-04 00:12:48,610 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:12:48,618 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:12:48,618 - root - INFO - dim=2
# 2024-09-04 00:12:53,184 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:12:53,185 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:12:53,188 - root - INFO - mu=0.8027553907738474,sigma=4.836103033253753
# 2024-09-04 00:12:53,188 - root - INFO - y_main=6.3497319290539656,u_shaded=9.260882148460655e-05,l_shaded=435369.92399313964
# 2024-09-04 00:12:53,189 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:12:53,194 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_64.pth
# 2024-09-04 00:12:53,194 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:12:53,194 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:12:53,195 - root - INFO - dim=2
# 2024-09-04 00:12:57,899 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:12:57,900 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:12:57,903 - root - INFO - mu=0.6382644483929549,sigma=4.580048132162354
# 2024-09-04 00:12:57,903 - root - INFO - y_main=4.347748845028498,u_shaded=0.00011434477288834148,l_shaded=165315.12146957085
# 2024-09-04 00:12:57,903 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:12:57,908 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_128.pth
# 2024-09-04 00:12:57,909 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:12:57,909 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:12:57,909 - root - INFO - dim=2
# 2024-09-04 00:13:02,518 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:02,520 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:02,522 - root - INFO - mu=0.5306559092417641,sigma=4.538160684972235
# 2024-09-04 00:13:02,523 - root - INFO - y_main=3.393562946505383,u_shaded=9.828680648065827e-05,l_shaded=117170.04432492742
# 2024-09-04 00:13:02,523 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:02,528 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_256.pth
# 2024-09-04 00:13:02,528 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:02,528 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:02,529 - root - INFO - dim=2
# 2024-09-04 00:13:06,872 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:06,873 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:06,876 - root - INFO - mu=0.5015108947750777,sigma=4.55771496280925
# 2024-09-04 00:13:06,876 - root - INFO - y_main=3.173298268663495,u_shaded=8.786095752276971e-05,l_shaded=114610.88276090182
# 2024-09-04 00:13:06,877 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:06,882 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_512.pth
# 2024-09-04 00:13:06,882 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:06,883 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:06,883 - root - INFO - dim=2
# 2024-09-04 00:13:11,314 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:11,315 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:11,318 - root - INFO - mu=0.3398984283616326,sigma=4.571396455860808
# 2024-09-04 00:13:11,318 - root - INFO - y_main=2.187250015908663,u_shaded=5.8681603484371155e-05,l_shaded=81525.76528292366
# 2024-09-04 00:13:11,319 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:11,323 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_1024.pth
# 2024-09-04 00:13:11,324 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:11,324 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:11,325 - root - INFO - dim=2
# 2024-09-04 00:13:15,664 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:15,665 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:15,667 - root - INFO - mu=0.16905029817780626,sigma=4.689428153672841
# 2024-09-04 00:13:15,667 - root - INFO - y_main=1.475877453356842,u_shaded=3.0173253709143355e-05,l_shaded=72190.23438188295
# 2024-09-04 00:13:15,668 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:15,672 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_2048.pth
# 2024-09-04 00:13:15,672 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:15,673 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:15,673 - root - INFO - dim=2
# 2024-09-04 00:13:20,132 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:20,133 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:20,136 - root - INFO - mu=0.0595426340474736,sigma=4.677305987915172
# 2024-09-04 00:13:20,136 - root - INFO - y_main=1.1469451098025056,u_shaded=2.4112189388211066e-05,l_shaded=54556.766443741035
# 2024-09-04 00:13:20,136 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:20,141 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_4096.pth
# 2024-09-04 00:13:20,141 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:20,141 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:20,141 - root - INFO - dim=2
# 2024-09-04 00:13:24,618 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:24,619 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:24,622 - root - INFO - mu=-0.017692061013055302,sigma=4.6270055572830415
# 2024-09-04 00:13:24,622 - root - INFO - y_main=0.9600811412534856,u_shaded=2.2662216369930664e-05,l_shaded=40673.68269476176
# 2024-09-04 00:13:24,622 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:24,627 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_8192.pth
# 2024-09-04 00:13:24,627 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:24,628 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:24,628 - root - INFO - dim=2
# 2024-09-04 00:13:29,013 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:29,014 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:29,016 - root - INFO - mu=-0.05042990459164368,sigma=4.145006063663082
# 2024-09-04 00:13:29,016 - root - INFO - y_main=0.8903691325636433,u_shaded=6.37623084322874e-05,l_shaded=12433.00645339724
# 2024-09-04 00:13:29,017 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:29,022 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_16384.pth
# 2024-09-04 00:13:29,022 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:29,023 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:29,023 - root - INFO - dim=2
# 2024-09-04 00:13:33,548 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:33,549 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:33,552 - root - INFO - mu=-0.13200765220367305,sigma=4.668571692799984
# 2024-09-04 00:13:33,552 - root - INFO - y_main=0.7378912284817173,u_shaded=1.5827803684959467e-05,l_shaded=34400.443416395094
# 2024-09-04 00:13:33,552 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:33,557 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_32768.pth
# 2024-09-04 00:13:33,558 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:33,558 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:33,558 - root - INFO - dim=2
# 2024-09-04 00:13:37,881 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:37,882 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:37,885 - root - INFO - mu=-0.2753605343170076,sigma=4.804955763875718
# 2024-09-04 00:13:37,885 - root - INFO - y_main=0.5304439075831479,u_shaded=8.311582151751024e-06,l_shaded=33852.84942804806
# 2024-09-04 00:13:37,885 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:37,891 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_65536.pth
# 2024-09-04 00:13:37,891 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:37,892 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:37,892 - root - INFO - dim=2
# 2024-09-04 00:13:42,376 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:42,377 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:42,379 - root - INFO - mu=-0.37356407963821114,sigma=4.942762110144822
# 2024-09-04 00:13:42,380 - root - INFO - y_main=0.4230930782265638,u_shaded=4.826961225818889e-06,l_shaded=37084.978409550065
# 2024-09-04 00:13:42,380 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:42,387 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_131072.pth
# 2024-09-04 00:13:42,387 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:42,388 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:42,388 - root - INFO - dim=2
# 2024-09-04 00:13:46,938 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:46,940 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:46,942 - root - INFO - mu=-0.5525966189610749,sigma=4.681309647593122
# 2024-09-04 00:13:46,942 - root - INFO - y_main=0.28015822748537267,u_shaded=5.8357104237435044e-06,l_shaded=13449.713355961356
# 2024-09-04 00:13:46,943 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:46,951 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_2/sign_model_262144.pth
# 2024-09-04 00:13:46,951 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:46,952 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:46,952 - root - INFO - dim=2
# 2024-09-04 00:13:51,482 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:13:51,483 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:51,486 - root - INFO - mu=-0.5321983549469106,sigma=4.400064128836822
# 2024-09-04 00:13:51,486 - root - INFO - y_main=0.2936308248103413,u_shaded=1.1687927693833721e-05,l_shaded=7376.762034923314
# 2024-09-04 00:13:51,486 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:13:51,688 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00:13:51,688 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/test/test_dataset_262144.pt']
# 2024-09-04 00:13:51,693 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_32.pth
# 2024-09-04 00:13:51,694 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:51,694 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:51,694 - root - INFO - dim=3
# 2024-09-04 00:13:56,373 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:13:56,374 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:13:56,379 - root - INFO - mu=0.5467295177518687,sigma=2.87217323122092
# 2024-09-04 00:13:56,380 - root - INFO - y_main=3.5215147983317596,u_shaded=0.004726680928533781,l_shaded=2623.6309711551453
# 2024-09-04 00:13:56,380 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:13:56,385 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_64.pth
# 2024-09-04 00:13:56,386 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:13:56,386 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:13:56,387 - root - INFO - dim=3
# 2024-09-04 00:14:00,771 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:14:00,772 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:14:00,777 - root - INFO - mu=0.5548888557443402,sigma=2.852646469416429
# 2024-09-04 00:14:00,777 - root - INFO - y_main=3.5883009141699556,u_shaded=0.005037816985363111,l_shaded=2555.8497833570837
# 2024-09-04 00:14:00,778 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:14:00,784 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_128.pth
# 2024-09-04 00:14:00,784 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:14:00,785 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:14:00,785 - root - INFO - dim=3
# 2024-09-04 00:14:05,242 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:14:05,243 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:14:05,248 - root - INFO - mu=0.467114701132074,sigma=2.7599991717273005
# 2024-09-04 00:14:05,249 - root - INFO - y_main=2.9316674231061586,u_shaded=0.005094663793863808,l_shaded=1686.9953008584437
# 2024-09-04 00:14:05,249 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:14:05,254 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_3/sign_model_256.pth
# 2024-09-04 00:14:05,255 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:14:05,255 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:14
- root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:13,534 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:13,534 - root - INFO - dim=4
# 2024-09-04 00:15:18,272 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:18,274 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:18,287 - root - INFO - mu=0.2180249120775672,sigma=1.5210310551925923
# 2024-09-04 00:15:18,287 - root - INFO - y_main=1.6520565610743396,u_shaded=0.04977300445152243,l_shaded=54.83476255983361
# 2024-09-04 00:15:18,288 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:18,296 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_1024.pth
# 2024-09-04 00:15:18,296 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:18,297 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:18,297 - root - INFO - dim=4
# 2024-09-04 00:15:22,677 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:22,679 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:22,688 - root - INFO - mu=0.22184832050542005,sigma=1.531082909212733
# 2024-09-04 00:15:22,688 - root - INFO - y_main=1.666665019893405,u_shaded=0.04906427787322032,l_shaded=56.61496324706766
# 2024-09-04 00:15:22,689 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:22,694 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_2048.pth
# 2024-09-04 00:15:22,695 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:22,695 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:22,696 - root - INFO - dim=4
# 2024-09-04 00:15:27,202 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:27,204 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:27,213 - root - INFO - mu=0.19220720278230374,sigma=1.5131909125415763
# 2024-09-04 00:15:27,213 - root - INFO - y_main=1.5567081630961557,u_shaded=0.047754718595693316,l_shaded=50.74556769074441
# 2024-09-04 00:15:27,213 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:27,219 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_4096.pth
# 2024-09-04 00:15:27,220 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:27,220 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:27,221 - root - INFO - dim=4
# 2024-09-04 00:15:31,696 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:31,698 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:31,706 - root - INFO - mu=0.16998925282671012,sigma=1.5002554005790405
# 2024-09-04 00:15:31,707 - root - INFO - y_main=1.4790717861892742,u_shaded=0.04674485879804648,l_shaded=46.799870722736145
# 2024-09-04 00:15:31,707 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:31,714 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_8192.pth
# 2024-09-04 00:15:31,715 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:31,716 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:31,716 - root - INFO - dim=4
# 2024-09-04 00:15:36,269 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:36,271 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:36,284 - root - INFO - mu=0.11487883853042094,sigma=1.4955288329018692
# 2024-09-04 00:15:36,284 - root - INFO - y_main=1.3028032657076776,u_shaded=0.041624593533839564,l_shaded=40.77628644610638
# 2024-09-04 00:15:36,285 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:36,294 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_16384.pth
# 2024-09-04 00:15:36,294 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:36,295 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:36,295 - root - INFO - dim=4
# 2024-09-04 00:15:40,811 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:40,813 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:40,821 - root - INFO - mu=0.08994835371871725,sigma=1.501594936808426
# 2024-09-04 00:15:40,822 - root - INFO - y_main=1.2301224760014366,u_shaded=0.0387572912807822,l_shaded=39.04300986880955
# 2024-09-04 00:15:40,822 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:40,829 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_32768.pth
# 2024-09-04 00:15:40,830 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:40,830 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:40,830 - root - INFO - dim=4
# 2024-09-04 00:15:45,234 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:45,236 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:45,245 - root - INFO - mu=0.060844938677959794,sigma=1.5001560666238596
# 2024-09-04 00:15:45,245 - root - INFO - y_main=1.150389578342792,u_shaded=0.03636544212788343,l_shaded=36.39158785161541
# 2024-09-04 00:15:45,246 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:45,255 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_4/sign_model_65536.pth
# 2024-09-04 00:15:45,255 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:15:45,256 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:15:45,256 - root - INFO - dim=4
# 2024-09-04 00:15:49,892 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:15:49,894 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:15:49,903 - root - INFO - mu=0.0071969713191141205,sigma=1.5112993696702337
# 2024-09-04 00:15:49,904 - root - INFO - y_main=1.0167097101160927,u_shaded=0.03132547042421768,l_shaded=32.99866277012706
# 2024-09-04 00:15:49,904 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:15:49,924 - root - INFO - idx=12
# ...
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/test/test_dataset_262144.pt']
# 2024-09-04 00:21:26,051 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_32.pth
# 2024-09-04 00:21:26,052 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:26,053 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:26,053 - root - INFO - dim=10
# 2024-09-04 00:21:31,011 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:31,042 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:31,110 - root - INFO - mu=0.0545059293937319,sigma=0.26547679142442004
# 2024-09-04 00:21:31,110 - root - INFO - y_main=1.1337203166079706,u_shaded=0.6152181479434178,l_shaded=2.089213006128501
# 2024-09-04 00:21:31,112 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:21:31,151 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_64.pth
# 2024-09-04 00:21:31,152 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:31,152 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:31,152 - root - INFO - dim=10
# 2024-09-04 00:21:35,676 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:35,683 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:35,748 - root - INFO - mu=0.026217885572106855,sigma=0.2707551550248945
# 2024-09-04 00:21:35,749 - root - INFO - y_main=1.0622283435727262,u_shaded=0.5694593532579394,l_shaded=1.9814040237182222
# 2024-09-04 00:21:35,751 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:21:35,789 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_128.pth
# 2024-09-04 00:21:35,790 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:35,790 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:35,791 - root - INFO - dim=10
# 2024-09-04 00:21:40,388 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:40,394 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:40,457 - root - INFO - mu=0.047271771855540344,sigma=0.3175769754493461
# 2024-09-04 00:21:40,458 - root - INFO - y_main=1.1149920526226424,u_shaded=0.536654525964612,l_shaded=2.316587706359217
# 2024-09-04 00:21:40,460 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:21:40,517 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_256.pth
# 2024-09-04 00:21:40,517 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:40,518 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:40,518 - root - INFO - dim=10
# 2024-09-04 00:21:44,914 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:44,921 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:44,982 - root - INFO - mu=0.048222792102847176,sigma=0.3451730839792128
# 2024-09-04 00:21:44,983 - root - INFO - y_main=1.1174363431272378,u_shaded=0.5047190629805346,l_shaded=2.4739782435951527
# 2024-09-04 00:21:44,984 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:21:45,046 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_512.pth
# 2024-09-04 00:21:45,047 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:45,047 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:45,047 - root - INFO - dim=10
# 2024-09-04 00:21:49,502 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:49,509 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:49,572 - root - INFO - mu=0.06364903638736903,sigma=0.3641744342887137
# 2024-09-04 00:21:49,573 - root - INFO - y_main=1.1578412991224258,u_shaded=0.5005812772647172,l_shaded=2.6780795344140946
# 2024-09-04 00:21:49,574 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:21:49,616 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_1024.pth
# 2024-09-04 00:21:49,617 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:49,617 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:49,618 - root - INFO - dim=10
# 2024-09-04 00:21:54,240 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:54,247 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:54,308 - root - INFO - mu=0.053214612576679005,sigma=0.3685996441673685
# 2024-09-04 00:21:54,309 - root - INFO - y_main=1.1303543567941952,u_shaded=0.4837433060802085,l_shaded=2.6412788680775368
# 2024-09-04 00:21:54,310 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:21:54,356 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/sign/20240903131914/dim_10/sign_model_2048.pth
# 2024-09-04 00:21:54,357 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:21:54,357 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:21:54,357 - root - INFO - dim=10
# 2024-09-04 00:21:58,976 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:21:58,983 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:21:59,050 - root - INFO - mu=0.028356322354274214,sigma=0.36439456629460243
# 2024-09-04 00:21:59,050 - root - INFO - y_main=1.0674715824868457,u_shaded=0.46127695275709,l_shaded=2.470306770381898
# 2024-09-04 00:21:59,053 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00