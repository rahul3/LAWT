# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

import logging
import math

import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
# sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/')
import datagenerator
from models import MatrixNet
from common import get_logger
# Out:
# 2024-09-03 22:13:41,770 - datagenerator - INFO - Using device: cuda

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904"

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-09-03 22:13:45,320 - root - INFO - Using device: cuda

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]
dim = 8

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-09-03 22:13:45,633 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'exp_model_{str(x)}.pth'), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-09-03 22:13:45,812 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/test/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(dim*dim).to(device)
model.load_state_dict(torch.load(models_lst[0]))
logger.info(model)
# Out:
# 2024-09-03 22:13:47,209 - root - INFO - MatrixNet(
#   (fc1): Linear(in_features=64, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (relu): ReLU()
# )

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(dim*dim).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        logger.info(f"{dim=}")
        for x, y in test_dataset:
            if dim == 1:
                predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                actuals.append(y.view(-1,1).to(device).to(torch.float64))
            else:
                predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                    
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
        mu = np.mean(np.log10(y_is))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-09-03 22:13:47,604 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_32.pth
# 2024-09-03 22:13:47,605 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:13:47,605 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:13:47,605 - root - INFO - dim=8
# 2024-09-03 22:13:53,799 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:13:53,822 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:13:53,875 - root - INFO - mu=-0.054890963549167726,sigma=0.26168017796846826
# 2024-09-03 22:13:53,875 - root - INFO - y_main=0.8812701019359189,u_shaded=0.48242394801028526,l_shaded=1.6098640951994925
# 2024-09-03 22:13:53,876 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:13:53,900 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_64.pth
# 2024-09-03 22:13:53,900 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:13:53,901 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:13:53,901 - root - INFO - dim=8
# 2024-09-03 22:14:00,103 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:14:00,124 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:14:00,165 - root - INFO - mu=-0.059916484579098726,sigma=0.3279410575649824
# 2024-09-03 22:14:00,166 - root - INFO - y_main=0.8711310935467971,u_shaded=0.409394927978371,l_shaded=1.8536365017793548
# 2024-09-03 22:14:00,168 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:14:00,188 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_128.pth
# 2024-09-03 22:14:00,188 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:14:00,189 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:14:00,189 - root - INFO - dim=8
# 2024-09-03 22:14:06,402 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:14:06,414 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:14:06,457 - root - INFO - mu=-0.06879199472685679,sigma=0.3562212426189919
# 2024-09-03 22:14:06,458 - root - INFO - y_main=0.8535088040449283,u_shaded=0.3758259488956384,l_shaded=1.9383368304472548
# 2024-09-03 22:14:06,459 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:14:06,476 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_256.pth
# 2024-09-03 22:14:06,477 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:14:06,477 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:14:06,477 - root - INFO - dim=8
# 2024-09-03 22:14:12,608 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:14:12,612 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:14:12,660 - root - INFO - mu=-0.09299345779396631,sigma=0.38560449837799543
# 2024-09-03 22:14:12,661 - root - INFO - y_main=0.8072471905176948,u_shaded=0.33220184782909257,l_shaded=1.9616026547027632
# 2024-09-03 22:14:12,662 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:14:12,678 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_512.pth
# 2024-09-03 22:14:12,679 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:14:12,679 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:14:12,679 - root - INFO - dim=8
# 2024-09-03 22:14:19,260 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:14:19,264 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:14:19,305 - root - INFO - mu=-0.11667233158945466,sigma=0.4090969535283864
# 2024-09-03 22:14:19,306 - root - INFO - y_main=0.7644123032188919,u_shaded=0.29800991587962683,l_shaded=1.9607608276646542
# 2024-09-03 22:14:19,306 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:14:19,323 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_1024.pth
# 2024-09-03 22:14:19,323 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:14:19,324 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:14:19,324 - root - INFO - dim=8
# 2024-09-03 22:14:25,662 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:14:25,673 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:14:25,724 - root - INFO - mu=-0.15145586653532825,sigma=0.4184266689188161
# 2024-09-03 22:14:25,725 - root - INFO - y_main=0.7055765418421683,u_shaded=0.2692262887489219,l_shaded=1.8491442968343732
# 2024-09-03 22:14:25,725 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:14
- root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)
# 2024-09-03 22:15:13,003 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_8/exp_model_262144.pth
# 2024-09-03 22:15:13,003 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:15:13,004 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:15:13,004 - root - INFO - dim=8
# 2024-09-03 22:15:19,830 - root - INFO -
# predicted.shape=torch.Size([32768, 64])
# actuals.shape=torch.Size([32768, 64])
# 2024-09-03 22:15:19,835 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:15:19,876 - root - INFO - mu=-0.41339808436036446,sigma=0.4439539504974665
# 2024-09-03 22:15:19,876 - root - INFO - y_main=0.38601298641522847,u_shaded=0.13888264057253355,l_shaded=1.0728916520231533
# 2024-09-03 22:15:19,881 - root - INFO - x_raw.shape=(2097152,), y_raw.shape=(2097152,)

# %%
mu_lst
# Out:
# [-0.054890963549167726,
#  -0.059916484579098726,
#  -0.06879199472685679,
#  -0.09299345779396631,
#  -0.11667233158945466,
#  -0.15145586653532825,
#  -0.18632722088775094,
#  -0.22490291428330758,
#  -0.27628114227121936,
#  -0.32330544611268675,
#  -0.3609260807531816,
#  -0.3833025114348787,
#  -0.40135515052750115,
#  -0.41339808436036446]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of e^x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
for dim in range(1, 2):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'exp_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $e^{X} $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Exp_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-03 22:45:33,069 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-03 22:45:33,071 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/test/test_dataset_262144.pt']
# 2024-09-03 22:45:33,088 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_32.pth
# 2024-09-03 22:45:33,089 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:45:33,090 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:45:33,091 - root - INFO - dim=1
# 2024-09-03 22:45:39,064 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:45:39,065 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22
- root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 22:46:19,593 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_8192.pth
# 2024-09-03 22:46:19,593 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:46:19,593 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:46:19,594 - root - INFO - dim=1
# 2024-09-03 22:46:25,351 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:46:25,352 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:46:25,353 - root - INFO - mu=-3.5289013527808435,sigma=0.2205408702585742
# 2024-09-03 22:46:25,353 - root - INFO - y_main=0.0002958684436514199,u_shaded=0.00017805647729682693,l_shaded=0.0004916312918107664
# 2024-09-03 22:46:25,354 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 22:46:25,358 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_16384.pth
# 2024-09-03 22:46:25,359 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:46:25,359 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:46:25,360 - root - INFO - dim=1
# 2024-09-03 22:46:31,042 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:46:31,043 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:46:31,044 - root - INFO - mu=-3.544528026757662,sigma=0.17407119890404688
# 2024-09-03 22:46:31,044 - root - INFO - y_main=0.0002854118320187586,u_shaded=0.0001911616517110586,l_shaded=0.0004261310421162869
# 2024-09-03 22:46:31,044 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 22:46:31,049 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_32768.pth
# 2024-09-03 22:46:31,049 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:46:31,049 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:46:31,049 - root - INFO - dim=1
# 2024-09-03 22:46:36,759 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:46:36,760 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:46:36,761 - root - INFO - mu=-3.7025695105158185,sigma=0.19822378644539104
# 2024-09-03 22:46:36,761 - root - INFO - y_main=0.00019834921658171598,u_shaded=0.00012566279151204966,l_shaded=0.0003130792436264475
# 2024-09-03 22:46:36,762 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 22:46:36,766 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_65536.pth
# 2024-09-03 22:46:36,766 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:46:36,766 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:46:36,767 - root - INFO - dim=1
# 2024-09-03 22:46:42,419 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:46:42,420 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:46:42,422 - root - INFO - mu=-3.7816588755361806,sigma=0.21620530626693527
# 2024-09-03 22:46:42,422 - root - INFO - y_main=0.0001653259871263354,u_shaded=0.00010049300158754222,l_shaded=0.00027198592526353157
# 2024-09-03 22:46:42,422 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 22:46:42,427 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_131072.pth
# 2024-09-03 22:46:42,428 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:46:42,428 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:46:42,428 - root - INFO - dim=1
# 2024-09-03 22:46:48,046 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:46:48,047 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:46:48,048 - root - INFO - mu=-3.9489054674849013,sigma=0.2334952427966834
# 2024-09-03 22:46:48,048 - root - INFO - y_main=0.00011248497924307678,u_shaded=6.570513163658983e-05,l_shaded=0.0001925705076628943
# 2024-09-03 22:46:48,049 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-03 22:46:48,054 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_1/exp_model_262144.pth
# 2024-09-03 22:46:48,054 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:46:48,054 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:46:48,055 - root - INFO - dim=1
# 2024-09-03 22:46:53,739 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-03 22:46:53,740 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:46:53,741 - root - INFO - mu=-4.077442795558615,sigma=0.2926611934880938
# 2024-09-03 22:46:53,741 - root - INFO - y_main=8.366757938389589e-05,u_shaded=4.264773892812643e-05,l_shaded=0.0001641415000161663
# 2024-09-03 22:46:53,741 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples", fontsize=14)
plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title(r"Neural Net Approximation of $e^{X} $ " + f" with dim={dim}", fontsize=18)

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in range(1, -5, -1)])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, f"shaded_plot_dim_{dim}.png"))
# Show the plot


plt.show()

# %% [markdown]
# # Loop

# %%
for dim in range(2, 11):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'exp_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $e^{X} $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Exp_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-03 22:27:31,303 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-03 22:27:31,304 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model
- root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:28:49,867 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_4096.pth
# 2024-09-03 22:28:49,867 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:28:49,868 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:28:49,868 - root - INFO - dim=2
# 2024-09-03 22:29:01,150 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:01,151 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:01,154 - root - INFO - mu=-1.908216429187935,sigma=0.3474992760050361
# 2024-09-03 22:29:01,155 - root - INFO - y_main=0.012353316566641794,u_shaded=0.005549888970107798,l_shaded=0.027496843813922738
# 2024-09-03 22:29:01,155 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:01,161 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_8192.pth
# 2024-09-03 22:29:01,161 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:01,162 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:01,162 - root - INFO - dim=2
# 2024-09-03 22:29:12,239 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:12,240 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:12,242 - root - INFO - mu=-2.1043851014580413,sigma=0.4641191600870571
# 2024-09-03 22:29:12,243 - root - INFO - y_main=0.007863482027971203,u_shaded=0.002700820606202794,l_shaded=0.022894652633431215
# 2024-09-03 22:29:12,243 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:12,249 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_16384.pth
# 2024-09-03 22:29:12,249 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:12,250 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:12,250 - root - INFO - dim=2
# 2024-09-03 22:29:23,720 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:23,721 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:23,723 - root - INFO - mu=-2.184458369684875,sigma=0.4343671793777233
# 2024-09-03 22:29:23,724 - root - INFO - y_main=0.006539456124893009,u_shaded=0.002405328798000883,l_shaded=0.017779060577889853
# 2024-09-03 22:29:23,724 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:23,730 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_32768.pth
# 2024-09-03 22:29:23,731 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:23,731 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:23,732 - root - INFO - dim=2
# 2024-09-03 22:29:34,758 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:34,759 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:34,762 - root - INFO - mu=-2.2848732191080607,sigma=0.3825334954738376
# 2024-09-03 22:29:34,762 - root - INFO - y_main=0.0051895151111163145,u_shaded=0.0021507666092617944,l_shaded=0.012521612978615147
# 2024-09-03 22:29:34,762 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:34,768 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_65536.pth
# 2024-09-03 22:29:34,769 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:34,769 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:34,769 - root - INFO - dim=2
# 2024-09-03 22:29:40,882 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:40,883 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:40,886 - root - INFO - mu=-2.349758281397587,sigma=0.328874428997735
# 2024-09-03 22:29:40,886 - root - INFO - y_main=0.004469322754546157,u_shaded=0.0020958842284593228,l_shaded=0.009530510136520036
# 2024-09-03 22:29:40,886 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:40,892 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_131072.pth
# 2024-09-03 22:29:40,892 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:40,892 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:40,893 - root - INFO - dim=2
# 2024-09-03 22:29:46,168 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:46,169 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:46,172 - root - INFO - mu=-2.5632244170343634,sigma=0.3887596434684096
# 2024-09-03 22:29:46,172 - root - INFO - y_main=0.0027338556705328813,u_shaded=0.0011169042397021168,l_shaded=0.006691680953147898
# 2024-09-03 22:29:46,172 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:46,178 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_2/exp_model_262144.pth
# 2024-09-03 22:29:46,179 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:46,179 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:46,179 - root - INFO - dim=2
# 2024-09-03 22:29:51,462 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-03 22:29:51,463 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:51,465 - root - INFO - mu=-2.4832040400238853,sigma=0.4398020795282156
# 2024-09-03 22:29:51,465 - root - INFO - y_main=0.0032869716624956712,u_shaded=0.0011939712803478288,l_shaded=0.009048946895022527
# 2024-09-03 22:29:51,466 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-03 22:29:51,764 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-03 22:29:51,765 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/test/test_dataset_262144.pt']
# 2024-09-03 22:29:51,769 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_32.pth
# 2024-09-03 22:29:51,770 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:51,770 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:51,770 - root - INFO - dim=3
# 2024-09-03 22:29:57,075 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:29:57,077 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:29:57,082 - root - INFO - mu=-0.5356323140053356,sigma=0.37528189548856755
# 2024-09-03 22:29:57,082 - root - INFO - y_main=0.2913182456989159,u_shaded=0.12276817233812086,l_shaded=0.6912729794767989
# 2024-09-03 22:29:57,083 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:29:57,088 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_64.pth
# 2024-09-03 22:29:57,089 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:29:57,089 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:29:57,089 - root - INFO - dim=3
# 2024-09-03 22:30:02,342 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:30:02,344 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:30:02,348 - root - INFO - mu=-0.7372915040296519,sigma=0.3817114251964577
# 2024-09-03 22:30:02,349 - root - INFO - y_main=0.18310849620773365,u_shaded=0.07603211487146017,l_shaded=0.4409810438673346
# 2024-09-03 22:30:02,349 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:30:02,354 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_128.pth
# 2024-09-03 22:30:02,355 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:30:02,355 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:30:02,355 - root - INFO - dim=3
# 2024-09-03 22:30:07,804 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:30:07,805 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:30:07,810 - root - INFO - mu=-0.8224350159650604,sigma=0.3921744467176081
# 2024-09-03 22:30:07,810 - root - INFO - y_main=0.15050987117860598,u_shaded=0.06100852670168271,l_shaded=0.3713123811851657
# 2024-09-03 22:30:07,811 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:30:07,815 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_256.pth
# 2024-09-03 22:30:07,816 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:30:07,816 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:30:07,816 - root - INFO - dim=3
# 2024-09-03 22:30:12,964 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:30:12,965 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:30:12,970 - root - INFO - mu=-1.03074223096022,sigma=0.385874293068784
# 2024-09-03 22:30:12,971 - root - INFO - y_main=0.09316606847585462,u_shaded=0.038316292150776754,l_shaded=0.22653330549552333
# 2024-09-03 22:30:12,971 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:30:12,975 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_512.pth
# 2024-09-03 22:30:12,976 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:30:12,976 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:30:12,976 - root - INFO - dim=3
# 2024-09-03 22:30:18,142 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:30:18,143 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:30:18,148 - root - INFO - mu=-1.1379605188539332,sigma=0.3990441226785295
# 2024-09-03 22:30:18,148 - root - INFO - y_main=0.07278459690589871,u_shaded=0.02903991617820063,l_shaded=0.18242468450135893
# 2024-09-03 22:30:18,149 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:30:18,153 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_1024.pth
# 2024-09-03 22:30:18,154 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:30:18,154 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:30:18,154 - root - INFO - dim=3
# 2024-09-03 22:30:23,357 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:30:23,358 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:30:23,363 - root - INFO - mu=-1.2695447859714821,sigma=0.39683508900501424
# 2024-09-03 22:30:23,363 - root - INFO - y_main=0.05375949915809833,u_shaded=0.021558578672701688,l_shaded=0.1340572490239865
# 2024-09-03 22:30:23,364 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:30:23,369 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_3/exp_model_2048.pth
# 2024-09-03 22:30:23,369 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:30
- root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:30:59,579 - root - INFO - dim=3
# 2024-09-03 22:31:04,755 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-03 22:31:04,756 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:04,761 - root - INFO - mu=-2.0224387896448945,sigma=0.40478313066272437
# 2024-09-03 22:31:04,761 - root - INFO - y_main=0.009496448346613659,u_shaded=0.0037391947018975305,l_shaded=0.024118169389290244
# 2024-09-03 22:31:04,762 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-03 22:31:05,075 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-03 22:31:05,076 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/test/test_dataset_262144.pt']
# 2024-09-03 22:31:05,087 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_32.pth
# 2024-09-03 22:31:05,087 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:05,088 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:05,088 - root - INFO - dim=4
# 2024-09-03 22:31:10,443 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:10,445 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:10,454 - root - INFO - mu=-0.31333933898599464,sigma=0.3337185159526157
# 2024-09-03 22:31:10,454 - root - INFO - y_main=0.4860272965113022,u_shaded=0.2253938931605204,l_shaded=1.0480431818348024
# 2024-09-03 22:31:10,455 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:10,471 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_64.pth
# 2024-09-03 22:31:10,471 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:10,472 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:10,472 - root - INFO - dim=4
# 2024-09-03 22:31:15,749 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:15,751 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:15,760 - root - INFO - mu=-0.4130878141626699,sigma=0.3973879449670404
# 2024-09-03 22:31:15,760 - root - INFO - y_main=0.3862888617105532,u_shaded=0.15471208566669378,l_shaded=0.9644953336296375
# 2024-09-03 22:31:15,761 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:15,770 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_128.pth
# 2024-09-03 22:31:15,770 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:15,770 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:15,771 - root - INFO - dim=4
# 2024-09-03 22:31:20,811 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:20,813 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:20,821 - root - INFO - mu=-0.4686433483000201,sigma=0.40622791005837805
# 2024-09-03 22:31:20,822 - root - INFO - y_main=0.3399042945119064,u_shaded=0.13339167979674194,l_shaded=0.866132952247736
# 2024-09-03 22:31:20,822 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:20,831 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_256.pth
# 2024-09-03 22:31:20,832 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:20,832 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:20,832 - root - INFO - dim=4
# 2024-09-03 22:31:25,957 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:25,959 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:25,967 - root - INFO - mu=-0.587285883582149,sigma=0.4025466569663581
# 2024-09-03 22:31:25,968 - root - INFO - y_main=0.25865097295791,u_shaded=0.10236876395349295,l_shaded=0.6535228445511652
# 2024-09-03 22:31:25,968 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:25,977 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_512.pth
# 2024-09-03 22:31:25,978 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:25,978 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:25,978 - root - INFO - dim=4
# 2024-09-03 22:31:31,026 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:31,028 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:31,037 - root - INFO - mu=-0.7359782895585524,sigma=0.4171355717338743
# 2024-09-03 22:31:31,037 - root - INFO - y_main=0.18366301544499203,u_shaded=0.07028880158382153,l_shaded=0.47990721825184113
# 2024-09-03 22:31:31,037 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:31,048 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_1024.pth
# 2024-09-03 22:31:31,050 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:31,050 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:31,054 - root - INFO - dim=4
# 2024-09-03 22:31:36,195 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:36,196 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:36,205 - root - INFO - mu=-0.8325894550140238,sigma=0.4144970702327915
# 2024-09-03 22:31:36,205 - root - INFO - y_main=0.14703155318802127,u_shaded=0.0566126487434672,l_shaded=0.3818630308368421
# 2024-09-03 22:31:36,206 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:36,214 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_2048.pth
# 2024-09-03 22:31:36,215 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:36,215 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:36,216 - root - INFO - dim=4
# 2024-09-03 22:31:41,356 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:41,358 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:41,367 - root - INFO - mu=-0.9190317204556658,sigma=0.4164856325528267
# 2024-09-03 22:31:41,367 - root - INFO - y_main=0.120494792890765,u_shaded=0.04618305382659754,l_shaded=0.314379277912251
# 2024-09-03 22:31:41,367 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:41,377 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_4096.pth
# 2024-09-03 22:31:41,378 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:41,378 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:41,379 - root - INFO - dim=4
# 2024-09-03 22:31:46,503 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:46,505 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:46,514 - root - INFO - mu=-0.9967752743104897,sigma=0.42135302497939703
# 2024-09-03 22:31:46,514 - root - INFO - y_main=0.10074528404951984,u_shaded=0.03818314535162741,l_shaded=0.26581393870910763
# 2024-09-03 22:31:46,515 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:46,525 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_8192.pth
# 2024-09-03 22:31:46,525 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:46,526 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:46,526 - root - INFO - dim=4
# 2024-09-03 22:31:51,757 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:51,759 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:51,767 - root - INFO - mu=-1.0788107219454581,sigma=0.42578123418045666
# 2024-09-03 22:31:51,768 - root - INFO - y_main=0.08340446061012946,u_shaded=0.03129017873171468,l_shaded=0.22231589372853144
# 2024-09-03 22:31:51,768 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:51,778 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_16384.pth
# 2024-09-03 22:31:51,779 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:51,779 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:51,779 - root - INFO - dim=4
# 2024-09-03 22:31:56,943 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:31:56,945 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:31:56,953 - root - INFO - mu=-1.1720425054657546,sigma=0.4317693501142604
# 2024-09-03 22:31:56,953 - root - INFO - y_main=0.06729107936320736,u_shaded=0.024899357709940763,l_shaded=0.1818556693154252
# 2024-09-03 22:31:56,954 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-03 22:31:56,965 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_4/exp_model_32768.pth
# 2024-09-03 22:31:56,966 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:31:56,966 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:31:56,967 - root - INFO - dim=4
# 2024-09-03 22:32:02,153 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-03 22:32:02,155 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:32:02,164 - root - INFO - mu=-1.264019726299895,sigma=0.4381307845322151
# ...
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/test/test_dataset_262144.pt']
# 2024-09-03 22:38:31,771 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_32.pth
# 2024-09-03 22:38:31,772 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:38:31,772 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:38:31,773 - root - INFO - dim=10
# 2024-09-03 22:38:36,921 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:38:36,930 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:38:36,998 - root - INFO - mu=-0.025322065610165825,sigma=0.24560462186290166
# 2024-09-03 22:38:36,999 - root - INFO - y_main=0.9433610358697423,u_shaded=0.5358871120877252,l_shaded=1.6606670022912415
# 2024-09-03 22:38:37,001 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:38:37,025 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_64.pth
# 2024-09-03 22:38:37,026 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:38:37,026 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:38:37,026 - root - INFO - dim=10
# 2024-09-03 22:38:42,163 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:38:42,181 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:38:42,242 - root - INFO - mu=inf,sigma=nan
# 2024-09-03 22:38:42,243 - root - INFO - y_main=inf,u_shaded=nan,l_shaded=nan
# 2024-09-03 22:38:42,245 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:38:42,269 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_128.pth
# 2024-09-03 22:38:42,270 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:38:42,271 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:38:42,271 - root - INFO - dim=10
# 2024-09-03 22:38:47,407 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:38:47,414 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:38:47,478 - root - INFO - mu=-0.03129463242917804,sigma=0.3088916789922976
# 2024-09-03 22:38:47,479 - root - INFO - y_main=0.930476410986636,u_shaded=0.45689214179567644,l_shaded=1.8949469080379884
# 2024-09-03 22:38:47,483 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:38:47,505 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_256.pth
# 2024-09-03 22:38:47,505 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:38:47,506 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:38:47,506 - root - INFO - dim=10
# 2024-09-03 22:38:52,623 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:38:52,650 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:38:52,711 - root - INFO - mu=-0.027714121120655456,sigma=0.3570773792712912
# 2024-09-03 22:38:52,712 - root - INFO - y_main=0.9381793700812744,u_shaded=0.41229540970658096,l_shaded=2.1348298082496155
# 2024-09-03 22:38:52,713 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:38:52,732 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_512.pth
# 2024-09-03 22:38:52,733 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:38:52,733 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:38:52,733 - root - INFO - dim=10
# 2024-09-03 22:38:57,723 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:38:57,729 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:38:57,789 - root - INFO - mu=-0.039397162441953196,sigma=0.36774612367046006
# 2024-09-03 22:38:57,790 - root - INFO - y_main=0.9132776667448378,u_shaded=0.39161265162976866,l_shaded=2.1298497203901166
# 2024-09-03 22:38:57,791 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:38:57,813 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_1024.pth
# 2024-09-03 22:38:57,813 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:38:57,813 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:38:57,814 - root - INFO - dim=10
# 2024-09-03 22:39:02,954 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:02,961 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:03,020 - root - INFO - mu=-0.0604644742584077,sigma=0.3750583455510169
# 2024-09-03 22:39:03,020 - root - INFO - y_main=0.8700325997285832,u_shaded=0.36684041846910975,l_shaded=2.063449626814275
# 2024-09-03 22:39:03,022 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:03,043 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_2048.pth
# 2024-09-03 22:39:03,044 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:03,044 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:03,044 - root - INFO - dim=10
# 2024-09-03 22:39:08,426 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:08,432 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:08,492 - root - INFO - mu=-0.08411102384119257,sigma=0.38797426512252703
# 2024-09-03 22:39:08,492 - root - INFO - y_main=0.8239274577550196,u_shaded=0.3372210769618959,l_shaded=2.013090230772724
# 2024-09-03 22:39:08,494 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:08,516 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_4096.pth
# 2024-09-03 22:39:08,517 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:08,517 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:08,518 - root - INFO - dim=10
# 2024-09-03 22:39:13,974 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:13,981 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:14,040 - root - INFO - mu=-0.10851537112344607,sigma=0.3903924729396395
# 2024-09-03 22:39:14,041 - root - INFO - y_main=0.7789052460234082,u_shaded=0.3170240106754849,l_shaded=1.9137142987690456
# 2024-09-03 22:39:14,043 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:14,067 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_8192.pth
# 2024-09-03 22:39:14,068 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:14,068 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:14,069 - root - INFO - dim=10
# 2024-09-03 22:39:19,139 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:19,146 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:19,215 - root - INFO - mu=-0.14057881880380246,sigma=0.3906832788365717
# 2024-09-03 22:39:19,215 - root - INFO - y_main=0.7234710897652447,u_shaded=0.2942645205194797,l_shaded=1.7787071876762732
# 2024-09-03 22:39:19,224 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:19,263 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_16384.pth
# 2024-09-03 22:39:19,264 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:19,264 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:19,264 - root - INFO - dim=10
# 2024-09-03 22:39:24,497 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:24,515 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:24,576 - root - INFO - mu=-0.15802031157100888,sigma=0.3781007006144489
# 2024-09-03 22:39:24,577 - root - INFO - y_main=0.6949918126727725,u_shaded=0.2909906186346785,l_shaded=1.6598941297436844
# 2024-09-03 22:39:24,578 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:24,612 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_32768.pth
# 2024-09-03 22:39:24,613 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:24,613 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:24,614 - root - INFO - dim=10
# 2024-09-03 22:39:29,913 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:29,920 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:29,981 - root - INFO - mu=-0.18689634165655084,sigma=0.39772035599064637
# 2024-09-03 22:39:29,982 - root - INFO - y_main=0.6502848832196637,u_shaded=0.2602455441337343,l_shaded=1.6248901811233631
# 2024-09-03 22:39:29,983 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:30,045 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_65536.pth
# 2024-09-03 22:39:30,045 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:30,046 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:30,046 - root - INFO - dim=10
# 2024-09-03 22:39:35,143 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:35,149 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:35,210 - root - INFO - mu=-0.19164199479347907,sigma=0.39095900233931624
# 2024-09-03 22:39:35,210 - root - INFO - y_main=0.6432177272957077,u_shaded=0.26145623492126746,l_shaded=1.582402671835468
# 2024-09-03 22:39:35,214 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:35,323 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_131072.pth
# 2024-09-03 22:39:35,323 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:35,324 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:35,324 - root - INFO - dim=10
# 2024-09-03 22:39:40,528 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:40,535 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:40,597 - root - INFO - mu=-0.2116103799368552,sigma=0.4063347167513864
# 2024-09-03 22:39:40,598 - root - INFO - y_main=0.6143128785946935,u_shaded=0.2410210107097958,l_shaded=1.5657569093081591
# 2024-09-03 22:39:40,599 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-03 22:39:40,801 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901005904/dim_10/exp_model_262144.pth
# 2024-09-03 22:39:40,802 - root - INFO - len(test_dataset)=32768
# 2024-09-03 22:39:40,802 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-03 22:39:40,803 - root - INFO - dim=10
# 2024-09-03 22:39:46,081 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-03 22:39:46,088 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-03 22:39:46,150 - root - INFO - mu=-0.20268292184499373,sigma=0.3934769402441941
# 2024-09-03 22:39:46,151 - root - INFO - y_main=0.6270715221470644,u_shaded=0.2534195631355749,l_shaded=1.5516509026474465
# 2024-09-03 22:39:46,153 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)

# %%
mu
# Out:
# -0.20268292184499373
