# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

import logging
import math

import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
# sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/')
import datagenerator
from models import MatrixNet
from common import get_logger
# Out:
# 2024-09-01 00:56:27,485 - datagenerator - INFO - Using device: cuda

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245"

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-09-01 00:56:27,497 - root - INFO - Using device: cuda

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]
dim = 3

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-09-01 00:56:27,503 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'exp_model_{str(x)}.pth'), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-09-01 00:56:27,507 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/test/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(dim*dim).to(device)
model.load_state_dict(torch.load(models_lst[0]))
logger.info(model)
# Out:
# 2024-09-01 00:56:27,625 - root - INFO - MatrixNet(
#   (fc1): Linear(in_features=9, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=9, bias=True)
#   (relu): ReLU()
# )

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(dim*dim).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        logger.info(f"{dim=}")
        for x, y in test_dataset:
            if dim == 1:
                predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                actuals.append(y.view(-1,1).to(device).to(torch.float64))
            else:
                predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                    
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        mu = np.mean(np.log10(np.abs(np_predicted - np_actuals)))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(np.abs(np_predicted - np_actuals)) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-09-01 00:56:27,638 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_32.pth
# 2024-09-01 00:56:27,639 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:27,639 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:27,640 - root - INFO - dim=3
# 2024-09-01 00:56:33,005 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:56:33,007 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:56:33,016 - root - INFO - mu=-0.8167968317241509,sigma=0.271597731396978
# 2024-09-01 00:56:33,016 - root - INFO - y_main=0.15247658911291948,u_shaded=0.08158408307954708,l_shaded=0.28497115307211884
# 2024-09-01 00:56:33,017 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:56:33,022 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_64.pth
# 2024-09-01 00:56:33,022 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:33,023 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:33,023 - root - INFO - dim=3
# 2024-09-01 00:56:38,337 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:56:38,338 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:56:38,344 - root - INFO - mu=-1.0177369567088723,sigma=0.2652790488596862
# 2024-09-01 00:56:38,345 - root - INFO - y_main=0.09599818968817231,u_shaded=0.052117550325347,l_shaded=0.17682435889402015
# 2024-09-01 00:56:38,345 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:56:38,350 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_128.pth
# 2024-09-01 00:56:38,350 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:38,351 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:38,351 - root - INFO - dim=3
# 2024-09-01 00:56:43,715 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:56:43,716 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:56:43,721 - root - INFO - mu=-1.1036206169014235,sigma=0.26238005886807153
# 2024-09-01 00:56:43,722 - root - INFO - y_main=0.07877336232736595,u_shaded=0.04305259405856078,l_shaded=0.14413167773161387
# 2024-09-01 00:56:43,722 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:56:43,729 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_256.pth
# 2024-09-01 00:56:43,730 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:43,730 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:43,730 - root - INFO - dim=3
# 2024-09-01 00:56:49,098 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:56:49,099 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:56:49,107 - root - INFO - mu=-1.3133171195074949,sigma=0.26486011275389676
# 2024-09-01 00:56:49,108 - root - INFO - y_main=0.04860521633925945,u_shaded=0.02641330630490579,l_shaded=0.08944230715059812
# 2024-09-01 00:56:49,108 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:56:49,113 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_512.pth
# 2024-09-01 00:56:49,113 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:49,114 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:49,114 - root - INFO - dim=3
# 2024-09-01 00:56:54,368 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:56:54,370 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:56:54,378 - root - INFO - mu=-1.4206218570608167,sigma=0.2624275471765159
# 2024-09-01 00:56:54,378 - root - INFO - y_main=0.037964540074547595,u_shaded=0.02074677493987558,l_shaded=0.06947134228085351
# 2024-09-01 00:56:54,379 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:56:54,384 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_1024.pth
# 2024-09-01 00:56:54,384 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:54,384 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:54,385 - root - INFO - dim=3
# 2024-09-01 00:56:59,666 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:56:59,668 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:56:59,673 - root - INFO - mu=-1.550100084468352,sigma=0.2611783842632887
# 2024-09-01 00:56:59,674 - root - INFO - y_main=0.028177335012834967,u_shaded=0.015442639431450916,l_shaded=0.05141363378649698
# 2024-09-01 00:56:59,675 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:56:59,680 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_2048.pth
# 2024-09-01 00:56:59,680 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:56:59,681 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:56:59,681 - root - INFO - dim=3
# 2024-09-01 00:57:04,874 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:04,875 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:04,880 - root - INFO - mu=-1.6443327587039722,sigma=0.2578855381738006
# 2024-09-01 00:57:04,881 - root - INFO - y_main=0.02268126335675055,u_shaded=0.012525114453972024,l_shaded=0.04107265521195566
# 2024-09-01 00:57:04,881 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:04,886 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_4096.pth
# 2024-09-01 00:57:04,887 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:04,887 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:04,887 - root - INFO - dim=3
# 2024-09-01 00:57:10,197 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:10,199 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:10,205 - root - INFO - mu=-1.765902825082325,sigma=0.25604297415272176
# 2024-09-01 00:57:10,205 - root - INFO - y_main=0.017143408543920952,u_shaded=0.009507234383187867,l_shaded=0.030912928477233526
# 2024-09-01 00:57:10,205 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:10,211 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_8192.pth
# 2024-09-01 00:57:10,211 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:10,212 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:10,212 - root - INFO - dim=3
# 2024-09-01 00:57:15,472 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:15,474 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:15,480 - root - INFO - mu=-1.845846051300657,sigma=0.2519077397046345
# 2024-09-01 00:57:15,481 - root - INFO - y_main=0.014261130325324299,u_shaded=0.007984472124105718,l_shaded=0.025471920371775786
# 2024-09-01 00:57:15,481 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:15,486 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_16384.pth
# 2024-09-01 00:57:15,486 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:15,487 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:15,487 - root - INFO - dim=3
# 2024-09-01 00:57:20,873 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:20,874 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:20,881 - root - INFO - mu=-1.9326858030295486,sigma=0.25195647472524
# 2024-09-01 00:57:20,881 - root - INFO - y_main=0.011676540687133212,u_shaded=0.006536687487024174,l_shaded=0.02085790435735621
# 2024-09-01 00:57:20,882 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:20,887 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_32768.pth
# 2024-09-01 00:57:20,888 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:20,888 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:20,888 - root - INFO - dim=3
# 2024-09-01 00:57:26,300 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:26,302 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:26,307 - root - INFO - mu=-2.0429075874333087,sigma=0.2514651625973923
# 2024-09-01 00:57:26,308 - root - INFO - y_main=0.009059253502509745,u_shaded=0.005077234821881382,l_shaded=0.016164325051312826
# 2024-09-01 00:57:26,308 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:26,315 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_65536.pth
# 2024-09-01 00:57:26,315 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:26,315 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:26,316 - root - INFO - dim=3
# 2024-09-01 00:57:31,636 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:31,637 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:31,643 - root - INFO - mu=-2.1077357944503405,sigma=0.2522261324063341
# 2024-09-01 00:57:31,643 - root - INFO - y_main=0.00780304668998475,u_shaded=0.004365541017992964,l_shaded=0.013947306277762271
# 2024-09-01 00:57:31,643 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:31,654 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_131072.pth
# 2024-09-01 00:57:31,655 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:31,655 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:31,655 - root - INFO - dim=3
# 2024-09-01 00:57:36,928 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:36,929 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:36,934 - root - INFO - mu=-2.233107088414995,sigma=0.24844277925694408
# 2024-09-01 00:57:36,935 - root - INFO - y_main=0.005846459042722727,u_shaded=0.003299515191982362,l_shaded=0.010359425960908582
# 2024-09-01 00:57:36,935 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-01 00:57:36,950 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/exponential/20240901004245/dim_3/exp_model_262144.pth
# 2024-09-01 00:57:36,951 - root - INFO - len(test_dataset)=32768
# 2024-09-01 00:57:36,951 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-01 00:57:36,952 - root - INFO - dim=3
# 2024-09-01 00:57:42,152 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-01 00:57:42,154 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-01 00:57:42,159 - root - INFO - mu=-2.3038354085915724,sigma=0.2482212797874862
# 2024-09-01 00:57:42,159 - root - INFO - y_main=0.004967805585178832,u_shaded=0.0028050674691120587,l_shaded=0.008798038765158878
# 2024-09-01 00:57:42,160 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)

# %%
mu_lst
# Out:
# [-0.8167968317241509,
#  -1.0177369567088723,
#  -1.1036206169014235,
#  -1.3133171195074949,
#  -1.4206218570608167,
#  -1.550100084468352,
#  -1.6443327587039722,
#  -1.765902825082325,
#  -1.845846051300657,
#  -1.9326858030295486,
#  -2.0429075874333087,
#  -2.1077357944503405,
#  -2.233107088414995,
#  -2.3038354085915724]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of e^x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples")
# plt.ylabel("Relative Error")
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title(f"Shaded plot of the approximation of e^(X) - dim {dim}")

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in range(1, -5, -1)])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, f"shaded_plot_dim_{dim}.png"))
# Show the plot


plt.show()
