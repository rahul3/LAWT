# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
import datagenerator
from models import MatrixNet

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp"

# %%
import logging
import math

def get_logger(name=None, level=logging.INFO, log_file=None):
    """
    Creates and returns a logger with the specified name, level, and optional file handler.
    
    Args:
        name (str): Name of the logger. If None, the root logger is returned.
        level (int): Logging level (e.g., logging.INFO, logging.DEBUG).
        log_file (str): Optional. If provided, logs will be written to this file.

    Returns:
        logging.Logger: Configured logger.
    """
    logger = logging.getLogger(name)
    logger.setLevel(level)
    
    # Check if the logger already has handlers (to avoid adding duplicate handlers)
    if not logger.hasHandlers():
        # Create console handler and set level
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        
        # Create a formatter and set it for the console handler
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        console_handler.setFormatter(formatter)
        
        # Add the console handler to the logger
        logger.addHandler(console_handler)
        
        if log_file:
            file_handler = logging.FileHandler(log_file)
            file_handler.setLevel(level)
            file_handler.setFormatter(formatter)
            logger.addHandler(file_handler)
    
    return logger

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-08-30 01:52:11,565 - root - INFO - Using device: cuda

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-08-30 01:52:12,284 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, "exp_model_"+str(x)+".pth"), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, "train_dataset_"+str(x)+".pt"), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, "test_dataset_"+str(x)+".pt"), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-08-30 01:52:12,670 - root - INFO - models_lst=['/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_32.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_64.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_128.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_256.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_512.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_1024.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_2048.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_4096.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_8192.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_16384.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_32768.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_65536.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_131072.pth', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_262144.pth']
#
# train_lst=['/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_32.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_64.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_128.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_256.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_512.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_1024.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_2048.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_4096.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_8192.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_16384.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_32768.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_65536.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_131072.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/train_dataset_262144.pt']
#
# test_lst=['/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_32.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_64.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_128.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_256.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_512.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_1024.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_2048.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_4096.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_8192.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_16384.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_32768.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_65536.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_131072.pt', '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(1).to(device)
model.load_state_dict(torch.load(models_lst[0]))

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(1).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        for x, y in test_dataset:
            predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
            actuals.append(y.view(-1,1).to(device).to(torch.float64))
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        mu = np.mean(np.log10(np.abs(np_predicted - np_actuals)))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(np.abs(np_predicted - np_actuals)) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-08-30 01:53:43,788 - root - INFO - idx=0
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_32.pth
# 2024-08-30 01:53:43,788 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:53:43,789 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:53:49,695 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:53:49,696 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:53:49,697 - root - INFO - mu=-2.1394251571379916,sigma=0.23901091496300447
# 2024-08-30 01:53:49,697 - root - INFO - y_main=0.007253954762158997,u_shaded=0.004183732684246291,l_shaded=0.012577251861618111
# 2024-08-30 01:53:49,697 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:53:49,702 - root - INFO - idx=1
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_64.pth
# 2024-08-30 01:53:49,702 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:53:49,703 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:53:55,108 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:53:55,109 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:53:55,110 - root - INFO - mu=-2.1624803812940607,sigma=0.3154970718900765
# 2024-08-30 01:53:55,110 - root - INFO - y_main=0.006878909862153893,u_shaded=0.0033267682408307637,l_shaded=0.014223834504269955
# 2024-08-30 01:53:55,110 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:53:55,114 - root - INFO - idx=2
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_128.pth
# 2024-08-30 01:53:55,115 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:53:55,115 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:00,799 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:00,800 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:00,801 - root - INFO - mu=-2.426941673189791,sigma=0.2906040974913602
# 2024-08-30 01:54:00,801 - root - INFO - y_main=0.0037416083561237065,u_shaded=0.001916259095844869,l_shaded=0.007305709922510442
# 2024-08-30 01:54:00,801 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:00,805 - root - INFO - idx=3
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_256.pth
# 2024-08-30 01:54:00,806 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:00,806 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:06,392 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:06,393 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:06,394 - root - INFO - mu=-2.998154593015121,sigma=0.34723977573988446
# 2024-08-30 01:54:06,394 - root - INFO - y_main=0.0010042582472930156,u_shaded=0.00045144581486539486,l_shaded=0.0022340103597078393
# 2024-08-30 01:54:06,394 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:06,398 - root - INFO - idx=4
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_512.pth
# 2024-08-30 01:54:06,398 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:06,399 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:12,246 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:12,247 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:12,248 - root - INFO - mu=-2.9692707061350547,sigma=0.2577827280636457
# 2024-08-30 01:54:12,248 - root - INFO - y_main=0.0010733201776568595,u_shaded=0.0005928523774394024,l_shaded=0.0019431754811223714
# 2024-08-30 01:54:12,249 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:12,253 - root - INFO - idx=5
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_1024.pth
# 2024-08-30 01:54:12,254 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:12,254 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:17,763 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:17,764 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:17,765 - root - INFO - mu=-3.3681130764410967,sigma=0.32416006078891396
# 2024-08-30 01:54:17,765 - root - INFO - y_main=0.00042843695454630775,u_shaded=0.00020310792193386695,l_shaded=0.0009037472407436796
# 2024-08-30 01:54:17,766 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:17,771 - root - INFO - idx=6
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_2048.pth
# 2024-08-30 01:54:17,772 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:17,772 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:23,459 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:23,460 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:23,461 - root - INFO - mu=-3.8718895002950013,sigma=0.30962416819046884
# 2024-08-30 01:54:23,461 - root - INFO - y_main=0.000134310665097226,u_shaded=6.583947080588235e-05,l_shaded=0.0002739899719432055
# 2024-08-30 01:54:23,462 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:23,466 - root - INFO - idx=7
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_4096.pth
# 2024-08-30 01:54:23,466 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:23,467 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:29,214 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:29,215 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:29,216 - root - INFO - mu=-3.696411186060187,sigma=0.18861562298077195
# 2024-08-30 01:54:29,216 - root - INFO - y_main=0.00020118185763618558,u_shaded=0.00013030863363221404,l_shaded=0.0003106021352060336
# 2024-08-30 01:54:29,216 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:29,220 - root - INFO - idx=8
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_8192.pth
# 2024-08-30 01:54:29,221 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:29,221 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:35,041 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:35,042 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:35,043 - root - INFO - mu=-3.528719227611265,sigma=0.1852250327428608
# 2024-08-30 01:54:35,043 - root - INFO - y_main=0.00029599254467708113,u_shaded=0.00019322162919399022,l_shaded=0.00045342535858888653
# 2024-08-30 01:54:35,043 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:35,047 - root - INFO - idx=9
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_16384.pth
# 2024-08-30 01:54:35,048 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:35,048 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:40,525 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:40,526 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:40,527 - root - INFO - mu=-3.5455183836548567,sigma=0.16702118480655942
# 2024-08-30 01:54:40,527 - root - INFO - y_main=0.00028476172581843516,u_shaded=0.00019384760138424736,l_shaded=0.00041831438672463857
# 2024-08-30 01:54:40,528 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:40,532 - root - INFO - idx=10
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_32768.pth
# 2024-08-30 01:54:40,532 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:40,532 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:46,145 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:46,146 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:46,147 - root - INFO - mu=-3.7024871141812414,sigma=0.25848709087662625
# 2024-08-30 01:54:46,147 - root - INFO - y_main=0.00019838685187193863,u_shaded=0.00010940213437939746,l_shaded=0.0003597493158512844
# 2024-08-30 01:54:46,147 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:46,151 - root - INFO - idx=11
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_65536.pth
# 2024-08-30 01:54:46,152 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:46,152 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:51,698 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:51,699 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:51,700 - root - INFO - mu=-3.7811678307754435,sigma=0.26049339864765697
# 2024-08-30 01:54:51,700 - root - INFO - y_main=0.000165513022365926,u_shaded=9.085289501049014e-05,l_shaded=0.00030152655641342487
# 2024-08-30 01:54:51,701 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:51,705 - root - INFO - idx=12
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_131072.pth
# 2024-08-30 01:54:51,705 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:51,706 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:54:57,246 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:54:57,247 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:54:57,248 - root - INFO - mu=-3.9480632178553012,sigma=0.18475885845789972
# 2024-08-30 01:54:57,248 - root - INFO - y_main=0.0001127033388192815,u_shaded=7.365087718704632e-05,l_shaded=0.00017246288253641864
# 2024-08-30 01:54:57,249 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-08-30 01:54:57,253 - root - INFO - idx=13
# Loaded model: /home/rahulpadmanabhan/Development/ws1/masters_thesis_2/experiments/scalar/exp/exp_model_262144.pth
# 2024-08-30 01:54:57,254 - root - INFO - len(test_dataset)=32768
# 2024-08-30 01:54:57,254 - root - INFO - Starting to predict values in the test_dataset
# 2024-08-30 01:55:03,158 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-08-30 01:55:03,158 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-08-30 01:55:03,160 - root - INFO - mu=-4.076815040436035,sigma=0.34068775244746213
# 2024-08-30 01:55:03,160 - root - INFO - y_main=8.378860493636331e-05,u_shaded=3.823817946095125e-05,l_shaded=0.00018360001485822066
# 2024-08-30 01:55:03,160 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)

# %%
mu_lst
# Out:
# [-2.1394251571379916,
#  -2.1624803812940607,
#  -2.426941673189791,
#  -2.998154593015121,
#  -2.9692707061350547,
#  -3.3681130764410967,
#  -3.8718895002950013,
#  -3.696411186060187,
#  -3.528719227611265,
#  -3.5455183836548567,
#  -3.7024871141812414,
#  -3.7811678307754435,
#  -3.9480632178553012,
#  -4.076815040436035]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of e^x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples")
# plt.ylabel("Relative Error")
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title("Shaded plot of the approximation of e^x")

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, "shaded_plot_20240830.png"))
# Show the plot
plt.show()
