# %% [markdown]
# ### Shaded plot

# %%
import datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F

from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
import math

from scipy.linalg import expm, hadamard, signm
import numpy as np

import os

import seaborn as sns

import logging
import math

import matplotlib.pyplot as plt

# %%
import sys
sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/neuralnet')
# sys.path.insert(0, '/home/rahulpadmanabhan/Development/ws1/masters_thesis_2/LAWT/src/')
import datagenerator
from models import MatrixNet
from common import get_logger
# Out:
# 2024-09-04 00:43:02,114 - datagenerator - INFO - Using device: cuda

# %%
torch.set_default_dtype(torch.float64)

# %%
save_dir = "/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208"

# %%
logger = get_logger()

# %%
# Check if CUDA is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger.info(f"Using device: {device}")
# Out:
# 2024-09-04 00:43:02,563 - root - INFO - Using device: cuda

# %% [markdown]
# # Settings

# %%
dim = 1
operation = "cos"

# %%
test_samples = 2**15  # 16384
k_values = range(5, 19)
train_samples = [(2**k) + test_samples for k in k_values]
dim = dim

# %%
logger.info(f"{train_samples=}, {test_samples=}")

relative_errors = []
# Out:
# 2024-09-04 00:43:10,565 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768

# %%
train_vals = [2**k for k in range(5, 19)]
models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]

logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")
# Out:
# 2024-09-04 00:43:10,990 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_262144.pt']

# %%
test_lst[0]
# Out:
# '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/test/test_dataset_32.pt'

# %%
# Load the saved model
model = MatrixNet(dim*dim).to(device)
model.load_state_dict(torch.load(models_lst[0]))
logger.info(model)
# Out:
# 2024-09-04 00:43:12,806 - root - INFO - MatrixNet(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
mu_lst = []
sigma_lst = []
y_main_lst = []
u_shaded_lst = []
l_shaded_lst = []
for idx, train_val in enumerate(train_vals):

    # Load the saved model
    model = MatrixNet(dim*dim).to(device)
    model.load_state_dict(torch.load(models_lst[idx]))
    model.eval()

    # Loading the test dataset
    test_dataset = torch.load(test_lst[idx])

    logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
    logger.info(f"{len(test_dataset)=}")

    actuals = []
    predicted = []

    logger.info(f"Starting to predict values in the test_dataset")
    with torch.no_grad():
        logger.info(f"{dim=}")
        for x, y in test_dataset:
            if dim == 1:
                predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                actuals.append(y.view(-1,1).to(device).to(torch.float64))
            else:
                predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                    
    
        predicted = torch.cat(predicted, 0)
        actuals = torch.cat(actuals, 0)
        
        logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
        
        np_predicted = predicted.view(-1).cpu().numpy()
        np_actuals = actuals.view(-1).cpu().numpy()

        logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
        
        # mu = np.mean(np.log10(np_predicted))
        y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
        mu = np.mean(np.log10(y_is))
        sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
        
        y_main = 10**mu 
        
        u_shaded = 10**(mu - sigma)
        l_shaded = 10**(mu + sigma)
        
        logger.info(f"{mu=},{sigma=}")
        logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
        
        x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
        y_raw = np_actuals
        
        logger.info(f"{x_raw.shape=}, {y_raw.shape=}")

        mu_lst.append(mu)
        sigma_lst.append(sigma)
        y_main_lst.append(y_main)
        u_shaded_lst.append(u_shaded)
        l_shaded_lst.append(l_shaded)
# Out:
# 2024-09-04 00:43:13,757 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_32.pth
# 2024-09-04 00:43:13,757 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:43:13,758 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:43:13,758 - root - INFO - dim=1
# 2024-09-04 00:43:18,921 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:43:18,922 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:43:18,923 - root - INFO - mu=-2.334377867714573,sigma=0.23517851752936192
# 2024-09-04 00:43:18,923 - root - INFO - y_main=0.004630438626551857,u_shaded=0.002694285505645057,l_shaded=0.007957939806060056
# 2024-09-04 00:43:18,924 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:43
- root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:43:59,691 - root - INFO - mu=-1.9740059341690077,sigma=0.005304953273295619
# 2024-09-04 00:43:59,691 - root - INFO - y_main=0.010616810503650194,u_shaded=0.010487913880189626,l_shaded=0.010747291268602516
# 2024-09-04 00:43:59,691 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:43:59,699 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_16384.pth
# 2024-09-04 00:43:59,699 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:43:59,699 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:43:59,700 - root - INFO - dim=1
# 2024-09-04 00:44:04,909 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:44:04,910 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:44:04,911 - root - INFO - mu=-3.286215862027097,sigma=0.17592476959473427
# 2024-09-04 00:44:04,911 - root - INFO - y_main=0.0005173496242225206,u_shaded=0.00034503199426890065,l_shaded=0.0007757269996085922
# 2024-09-04 00:44:04,911 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:44:04,918 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_32768.pth
# 2024-09-04 00:44:04,919 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:44:04,919 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:44:04,919 - root - INFO - dim=1
# 2024-09-04 00:44:09,894 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:44:09,895 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:44:09,896 - root - INFO - mu=-2.7455805666703625,sigma=0.005090477617282446
# 2024-09-04 00:44:09,896 - root - INFO - y_main=0.0017964677836209172,u_shaded=0.0017755338471656674,l_shaded=0.0018176485358134236
# 2024-09-04 00:44:09,897 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:44:09,904 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_65536.pth
# 2024-09-04 00:44:09,904 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:44:09,905 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:44:09,905 - root - INFO - dim=1
# 2024-09-04 00:44:15,052 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:44:15,052 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:44:15,053 - root - INFO - mu=-2.394636516940106,sigma=0.0008623582694149297
# 2024-09-04 00:44:15,054 - root - INFO - y_main=0.004030542297075475,u_shaded=0.004022546978071497,l_shaded=0.004038553507783473
# 2024-09-04 00:44:15,054 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:44:15,062 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_131072.pth
# 2024-09-04 00:44:15,063 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:44:15,063 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:44:15,063 - root - INFO - dim=1
# 2024-09-04 00:44:20,120 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:44:20,121 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:44:20,122 - root - INFO - mu=-3.3212864644239475,sigma=0.09406415364316947
# 2024-09-04 00:44:20,123 - root - INFO - y_main=0.00047721439504818324,u_shaded=0.00038428141565684585,l_shaded=0.0005926218900072029
# 2024-09-04 00:44:20,123 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)
# 2024-09-04 00:44:20,133 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_1/cos_model_262144.pth
# 2024-09-04 00:44:20,133 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:44:20,134 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:44:20,134 - root - INFO - dim=1
# 2024-09-04 00:44:25,134 - root - INFO -
# predicted.shape=torch.Size([32768, 1])
# actuals.shape=torch.Size([32768, 1])
# 2024-09-04 00:44:25,135 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:44:25,136 - root - INFO - mu=-2.891202161200188,sigma=0.024910832053036343
# 2024-09-04 00:44:25,136 - root - INFO - y_main=0.0012846885067590574,u_shaded=0.0012130731961677744,l_shaded=0.0013605317177996193
# 2024-09-04 00:44:25,137 - root - INFO - x_raw.shape=(32768,), y_raw.shape=(32768,)

# %%
mu_lst
# Out:
# [-2.334377867714573,
#  -2.1433394002697677,
#  -2.3068136136638504,
#  -2.509320958007799,
#  -2.953830087187856,
#  -3.4427514613385024,
#  -3.542850767909909,
#  -3.20010270210624,
#  -1.9740059341690077,
#  -3.286215862027097,
#  -2.7455805666703625,
#  -2.394636516940106,
#  -3.3212864644239475,
#  -2.891202161200188]

# %% [markdown]
# ### Rough Sketch

# %%
plt.figure(figsize=(15, 8))

plt.grid()
# plt.plot(x_raw, y_raw)
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8)
plt.xlabel("Number of samples")


plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in k_values])
plt.xscale('log', base=2)
plt.yscale('log', base=10)


plt.title("Shaded plot of the approximation of cos x")
plt.show()

# %% [markdown]
# ## Shaded Plot

# %%
# Your existing data
# train_vals = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144]
# mu_lst = [0.0025189347, -0.0030112644, 0.0018056722, 0.00024630464, -0.0018855985, 0.00081260776, -0.0035950374, -0.0015076925, 0.00010364427, -0.0008442651, 0.00014675909, 0.0005134512, 0.0008943669, 0.00058361713]

# # Upper and lower bounds
# upper_bounds = [0.87437994331586, 0.8589856091986053, 0.8720893378924958, 0.8655245974598067, 0.8616714614469541, 0.866559207650375, 0.8581177330481463, 0.8626829584139304, 0.8656539427892145, 0.8637384055476058, 0.865978438284143, 0.8664403425328335, 0.8658090298992606, 0.8661159388212001]
# lower_bounds = [1.157011517572361, 1.1481313700565632, 1.1562463306422472, 1.156679915576484, 1.1505012466549305, 1.1583157837635798, 1.1462069789816558, 1.151153918054339, 1.1557475383338336, 1.1532653376919344, 1.1555438736045827, 1.1568797971867635, 1.1597559860949047, 1.1576871250884513]

k_values = range(5, 19)

plt.figure(figsize=(15, 8))
plt.grid(True, which="both", ls="-", alpha=0.2)


# Plot the main curve
plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')

u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
# Add the shaded region
plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')

plt.xlabel("Number of samples", fontsize=14)
plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
plt.xscale('log', base=2)
plt.yscale('log', base=10)
plt.title(r"Neural Net Approximation of $\text{cos}\left(X\right)$ " + f" with dim={dim}", fontsize=18)

# Set x-ticks
# plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
plt.xticks([2**k for k in k_values])
plt.yticks([10**k for k in range(1, -5, -1)])

# Set y-ticks
# y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
# plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])

# y_ticks = np.arange(10**0, 10**-4)
# plt.yticks(y_ticks)

# Add legend
plt.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

plt.savefig(os.path.join(save_dir, f"shaded_plot_dim_{dim}.png"))
# Show the plot


plt.show()

# %% [markdown]
# # Loop

# %%
for dim in range(1, 2):

    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/np.abs(np_actuals)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $log\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Exp_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot

# %%
for dim in range(2, 11):
    
    test_samples = 2**15  # 16384
    k_values = range(5, 19)
    train_samples = [(2**k) + test_samples for k in k_values]
    dim = dim

    logger.info(f"{train_samples=}, {test_samples=}")

    train_vals = [2**k for k in range(5, 19)]
    models_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", f'{operation}_model_{str(x)}.pth'), train_vals)]
    train_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "train", f'train_dataset_{str(x)}.pt'), train_vals)]
    test_lst = [*map(lambda x: os.path.join(save_dir, f"dim_{dim}", "test", f'test_dataset_{str(x)}.pt'), train_vals)]
    
    logger.info(f"{models_lst=}\n\n{train_lst=}\n\n{test_lst=}")

    
    mu_lst = []
    sigma_lst = []
    y_main_lst = []
    u_shaded_lst = []
    l_shaded_lst = []
    for idx, train_val in enumerate(train_vals):
    
        # Load the saved model
        model = MatrixNet(dim*dim).to(device)
        model.load_state_dict(torch.load(models_lst[idx]))
        model.eval()
    
        # Loading the test dataset
        test_dataset = torch.load(test_lst[idx])
    
        logger.info(f"{idx=}\nLoaded model: {models_lst[idx]}")
        logger.info(f"{len(test_dataset)=}")
    
        actuals = []
        predicted = []
    
        logger.info(f"Starting to predict values in the test_dataset")
        with torch.no_grad():
            logger.info(f"{dim=}")
            for x, y in test_dataset:
                if dim == 1:
                    predicted.append(model(x.view(-1, 1).to(device).to(torch.float64)))
                    actuals.append(y.view(-1,1).to(device).to(torch.float64))
                else:
                    predicted.append(model(x.view(1, dim*dim).to(device).to(torch.float64)))
                    actuals.append(y.view(1, dim*dim).to(device).to(torch.float64))
                        
        
            predicted = torch.cat(predicted, 0)
            actuals = torch.cat(actuals, 0)
            
            logger.info(f"\n{predicted.shape=}\n{actuals.shape=}")
            
            np_predicted = predicted.view(-1).cpu().numpy()
            np_actuals = actuals.view(-1).cpu().numpy()
    
            logger.info(f"{np_predicted.dtype=},{np_actuals.dtype=}")
            
            # mu = np.mean(np.log10(np_predicted))
            y_is = np.abs(np_predicted - np_actuals)/(np.abs(np_actuals) + 1e-5)
            mu = np.mean(np.log10(y_is))
            sigma = (np_predicted.shape[0] -1)**-1 * np.sum((np.log10(y_is) - mu)**2)
            
            y_main = 10**mu 
            
            u_shaded = 10**(mu - sigma)
            l_shaded = 10**(mu + sigma)
            
            logger.info(f"{mu=},{sigma=}")
            logger.info(f"{y_main=},{u_shaded=},{l_shaded=}")
            
            x_raw = np.repeat(train_vals[idx], np_predicted.shape[0])
            y_raw = np_actuals
            
            logger.info(f"{x_raw.shape=}, {y_raw.shape=}")
    
            mu_lst.append(mu)
            sigma_lst.append(sigma)
            y_main_lst.append(y_main)
            u_shaded_lst.append(u_shaded)
            l_shaded_lst.append(l_shaded)
    
    # Plot
    k_values = range(5, 19)
    
    plt.figure(figsize=(15, 8))
    plt.grid(True, which="both", ls="-", alpha=0.2)
    
    
    # Plot the main curve
    plt.plot(train_vals, 10**np.array(mu_lst), color='blue', marker='x', linestyle='dotted', linewidth=2, markersize=8, label='Shaded Plot')
    
    u_shaded_lst = [0 if math.isnan(x) else x for x in u_shaded_lst]
    l_shaded_lst = [0 if math.isnan(x) else x for x in l_shaded_lst]
    # Add the shaded region
    plt.fill_between(train_vals, u_shaded_lst, l_shaded_lst, alpha=0.3, color='grey', label='Bounds')
    
    plt.xlabel("Number of samples", fontsize=14)
    plt.ylabel(r"Relative Error - $L_{Frobenius}\left(\mu\right)$", fontsize=14)
    plt.xscale('log', base=2)
    plt.yscale('log', base=10)
    plt.title(r"Neural Net Approximation of $\text{cos}\left(X\right) $ " + f" with dim={dim}", fontsize=18)
    
    # Set x-ticks
    # plt.xticks([2**k for k in k_values], [f'2^{k}' for k in k_values], rotation=45)
    plt.xticks([2**k for k in k_values])
    plt.yticks([10**k for k in range(1, -5, -1)])
    
    # Set y-ticks
    # y_ticks = [0.8, 0.9, 1.0, 1.1, 1.2]
    # plt.yticks(y_ticks, [f'{y:.1f}' for y in y_ticks])
    
    # y_ticks = np.arange(10**0, 10**-4)
    # plt.yticks(y_ticks)
    
    # Add legend
    plt.legend()
    
    # Adjust layout to prevent cutting off labels
    plt.tight_layout()
    
    plt.savefig(os.path.join(save_dir, f"Cos_shaded_plot_dim_{dim}_v1.png"))
    # Show the plot
# Out:
# 2024-09-04 00:44:58,409 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00:44:58,410 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/test/test_dataset_262144.pt']
# 2024-09-04 00:44:58,431 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_32.pth
# 2024-09-04 00:44:58,432 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:44:58,432 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:44:58,433 - root - INFO - dim=2
# 2024-09-04 00:45:02,885 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:02,886 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:02,888 - root - INFO - mu=-0.8329315961444487,sigma=0.5945956732072304
# 2024-09-04 00:45:02,889 - root - INFO - y_main=0.14691576601242295,u_shaded=0.037365666274266185,l_shaded=0.5776490681201133
# 2024-09-04 00:45:02,889 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:02,897 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_64.pth
# 2024-09-04 00:45:02,897 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:02,898 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:02,898 - root - INFO - dim=2
# 2024-09-04 00:45:07,377 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:07,378 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:07,380 - root - INFO - mu=-1.162068276824786,sigma=0.5692306042302937
# 2024-09-04 00:45:07,381 - root - INFO - y_main=0.06885440396237195,u_shaded=0.018565263556521775,l_shaded=0.2553655610963878
# 2024-09-04 00:45:07,381 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:07,389 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_128.pth
# 2024-09-04 00:45:07,390 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:07,390 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:07,391 - root - INFO - dim=2
# 2024-09-04 00:45:11,753 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:11,754 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:11,757 - root - INFO - mu=-1.197364218190054,sigma=0.6658590160749188
# 2024-09-04 00:45:11,757 - root - INFO - y_main=0.06347983391336966,u_shaded=0.013701772922235865,l_shaded=0.2940998465336869
# 2024-09-04 00:45:11,758 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:11,766 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_256.pth
# 2024-09-04 00:45:11,766 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:11,767 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:11,767 - root - INFO - dim=2
# 2024-09-04 00:45:16,211 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:16,212 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:16,215 - root - INFO - mu=-1.4092557421132583,sigma=0.5688813901301383
# 2024-09-04 00:45:16,215 - root - INFO - y_main=0.03897124299233965,u_shaded=0.010516297601888276,l_shaded=0.14441943713111344
# 2024-09-04 00:45:16,215 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:16,224 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_512.pth
# 2024-09-04 00:45:16,225 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:16,225 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:16,225 - root - INFO - dim=2
# 2024-09-04 00:45:20,685 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:20,686 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:20,689 - root - INFO - mu=-1.5252609317261236,sigma=0.6304066999957282
# 2024-09-04 00:45:20,689 - root - INFO - y_main=0.02983589487514082,u_shaded=0.006987669702221436,l_shaded=0.12739305962293246
# 2024-09-04 00:45:20,689 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:20,698 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_1024.pth
# 2024-09-04 00:45:20,698 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:20,699 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:20,699 - root - INFO - dim=2
# 2024-09-04 00:45:25,053 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:25,054 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:25,057 - root - INFO - mu=-1.5414722106836978,sigma=0.46749147274699043
# 2024-09-04 00:45:25,057 - root - INFO - y_main=0.028742715045047502,u_shaded=0.009795718957362715,l_shaded=0.08433721626321762
# 2024-09-04 00:45:25,058 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:25,068 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_2048.pth
# 2024-09-04 00:45:25,069 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:25,069 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:25,069 - root - INFO - dim=2
# 2024-09-04 00:45:29,647 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:29,649 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:29,651 - root - INFO - mu=-1.746601219838759,sigma=0.6500285283906764
# 2024-09-04 00:45:29,651 - root - INFO - y_main=0.017922507886462786,u_shaded=0.004012086167384619,l_shaded=0.08006216106512827
# 2024-09-04 00:45:29,651 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:29,659 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_4096.pth
# 2024-09-04 00:45:29,660 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:29,660 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:29,660 - root - INFO - dim=2
# 2024-09-04 00:45:34,360 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:34,362 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:34,364 - root - INFO - mu=-1.8906727219253896,sigma=0.711639516496648
# 2024-09-04 00:45:34,365 - root - INFO - y_main=0.012862555985260428,u_shaded=0.0024985483706123674,l_shaded=0.06621658736725196
# 2024-09-04 00:45:34,365 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:34,374 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_8192.pth
# 2024-09-04 00:45:34,374 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:34,375 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:34,375 - root - INFO - dim=2
# 2024-09-04 00:45:39,106 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:39,108 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:39,110 - root - INFO - mu=-1.9329034054288556,sigma=0.544721200715528
# 2024-09-04 00:45:39,111 - root - INFO - y_main=0.011670691644746068,u_shaded=0.0033294722063499566,l_shaded=0.040908899376596676
# 2024-09-04 00:45:39,111 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:39,121 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_16384.pth
# 2024-09-04 00:45:39,121 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:39,122 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:39,122 - root - INFO - dim=2
# 2024-09-04 00:45:43,877 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:43,878 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:43,880 - root - INFO - mu=-1.9933138779833457,sigma=0.7083758660868648
# 2024-09-04 00:45:43,881 - root - INFO - y_main=0.01015514484024608,u_shaded=0.001987514271980327,l_shaded=0.05188740940391968
# 2024-09-04 00:45:43,881 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:43,892 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_32768.pth
# 2024-09-04 00:45:43,893 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:43,893 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:43,894 - root - INFO - dim=2
# 2024-09-04 00:45:48,443 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:48,444 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:48,447 - root - INFO - mu=-2.1728579247322912,sigma=0.6818252951723472
# 2024-09-04 00:45:48,447 - root - INFO - y_main=0.006716485403574692,u_shaded=0.0013973872620209901,l_shaded=0.0322825156651201
# 2024-09-04 00:45:48,448 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:48,460 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_65536.pth
# 2024-09-04 00:45:48,460 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:48,460 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:48,461 - root - INFO - dim=2
# 2024-09-04 00:45:52,926 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:52,927 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:52,930 - root - INFO - mu=-2.3197471514803008,sigma=0.7005501917625269
# 2024-09-04 00:45:52,930 - root - INFO - y_main=0.004789088344013733,u_shaded=0.0009543389663729004,l_shaded=0.024032726290049006
# 2024-09-04 00:45:52,930 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:52,945 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_131072.pth
# 2024-09-04 00:45:52,945 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:52,946 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:52,946 - root - INFO - dim=2
# 2024-09-04 00:45:57,297 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:45:57,298 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:45:57,300 - root - INFO - mu=-2.3732525338099104,sigma=0.6731294349685658
# 2024-09-04 00:45:57,300 - root - INFO - y_main=0.0042339669749644334,u_shaded=0.000898706807161325,l_shaded=0.019946968468740583
# 2024-09-04 00:45:57,301 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:45:57,325 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_2/cos_model_262144.pth
# 2024-09-04 00:45:57,326 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:45:57,327 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:45:57,327 - root - INFO - dim=2
# 2024-09-04 00:46:01,774 - root - INFO -
# predicted.shape=torch.Size([32768, 4])
# actuals.shape=torch.Size([32768, 4])
# 2024-09-04 00:46:01,775 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:46:01,778 - root - INFO - mu=-2.3275901669902037,sigma=0.642428635779448
# 2024-09-04 00:46:01,778 - root - INFO - y_main=0.004703377453978678,u_shaded=0.0010714729148380594,l_shaded=0.020646121024849612
# 2024-09-04 00:46:01,778 - root - INFO - x_raw.shape=(131072,), y_raw.shape=(131072,)
# 2024-09-04 00:46:02,144 - root - INFO - train_samples=[32800, 32832, 32896, 33024, 33280, 33792, 34816, 36864, 40960, 49152, 65536, 98304, 163840, 294912], test_samples=32768
# 2024-09-04 00:46:02,145 - root - INFO - models_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_32.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_64.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_128.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_256.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_512.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_1024.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_2048.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_4096.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_8192.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_16384.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_32768.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_65536.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_131072.pth', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_262144.pth']
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/test/test_dataset_262144.pt']
# 2024-09-04 00:46:02,154 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_32.pth
# 2024-09-04 00:46:02,154 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:46:02,155 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:46:02,155 - root - INFO - dim=3
# 2024-09-04 00:46:06,543 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:46:06,546 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:46:06,553 - root - INFO - mu=-0.2751007766026764,sigma=0.4214310125400365
# 2024-09-04 00:46:06,553 - root - INFO - y_main=0.530761268537816,u_shaded=0.20112599742018686,l_shaded=1.4006519683844554
# 2024-09-04 00:46:06,554 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:46:06,564 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_64.pth
# 2024-09-04 00:46:06,565 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:46:06,565 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:46:06,565 - root - INFO - dim=3
# 2024-09-04 00:46:10,999 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:46:11,000 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:46:11,007 - root - INFO - mu=-0.43361941468236864,sigma=0.45608156011479367
# 2024-09-04 00:46:11,007 - root - INFO - y_main=0.36845171752951583,u_shaded=0.1289136856845826,l_shaded=1.0530818929699248
# 2024-09-04 00:46:11,007 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:46:11,017 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_128.pth
# 2024-09-04 00:46:11,018 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:46:11,018 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:46:11,018 - root - INFO - dim=3
# 2024-09-04 00:46:15,476 - root - INFO -
# predicted.shape=torch.Size([32768, 9])
# actuals.shape=torch.Size([32768, 9])
# 2024-09-04 00:46:15,477 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:46:15,483 - root - INFO - mu=-0.5598085401085134,sigma=0.4484842885685175
# 2024-09-04 00:46:15,484 - root - INFO - y_main=0.2755443180159554,u_shaded=0.09810862098753116,l_shaded=0.7738837874454214
# 2024-09-04 00:46:15,484 - root - INFO - x_raw.shape=(294912,), y_raw.shape=(294912,)
# 2024-09-04 00:46:15,494 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_3/cos_model_256.pth
# 2024-09-04 00:46:15,495 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:46:15,495 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:46
- root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_512.pth
# 2024-09-04 00:47:23,418 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:23,419 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:23,419 - root - INFO - dim=4
# 2024-09-04 00:47:28,023 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:28,025 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:28,034 - root - INFO - mu=-0.5175366231444987,sigma=0.4596125913234619
# 2024-09-04 00:47:28,035 - root - INFO - y_main=0.3037129966334912,u_shaded=0.10540246934119109,l_shaded=0.8751368435734286
# 2024-09-04 00:47:28,035 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:28,048 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_1024.pth
# 2024-09-04 00:47:28,048 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:28,049 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:28,049 - root - INFO - dim=4
# 2024-09-04 00:47:32,666 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:32,668 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:32,677 - root - INFO - mu=-0.6289551203831745,sigma=0.4780048082342445
# 2024-09-04 00:47:32,678 - root - INFO - y_main=0.23498756424218026,u_shaded=0.0781699926968646,l_shaded=0.7063983690341017
# 2024-09-04 00:47:32,678 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:32,691 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_2048.pth
# 2024-09-04 00:47:32,691 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:32,692 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:32,692 - root - INFO - dim=4
# 2024-09-04 00:47:37,124 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:37,126 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:37,134 - root - INFO - mu=-0.7074571119679273,sigma=0.48364769536350827
# 2024-09-04 00:47:37,135 - root - INFO - y_main=0.19612948503365743,u_shaded=0.06440138283205593,l_shaded=0.597297343752388
# 2024-09-04 00:47:37,135 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:37,150 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_4096.pth
# 2024-09-04 00:47:37,150 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:37,150 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:37,151 - root - INFO - dim=4
# 2024-09-04 00:47:41,712 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:41,714 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:41,723 - root - INFO - mu=-0.7835513625817657,sigma=0.4906399518946044
# 2024-09-04 00:47:41,723 - root - INFO - y_main=0.16460712793729804,u_shaded=0.05318739076962241,l_shaded=0.5094347772224502
# 2024-09-04 00:47:41,723 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:41,737 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_8192.pth
# 2024-09-04 00:47:41,738 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:41,738 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:41,739 - root - INFO - dim=4
# 2024-09-04 00:47:46,294 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:46,296 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:46,305 - root - INFO - mu=-0.8660594202029152,sigma=0.5015933791578234
# 2024-09-04 00:47:46,305 - root - INFO - y_main=0.13612584222468488,u_shaded=0.04288912643625898,l_shaded=0.4320499497447007
# 2024-09-04 00:47:46,306 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:46,319 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_16384.pth
# 2024-09-04 00:47:46,320 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:46,320 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:46,320 - root - INFO - dim=4
# 2024-09-04 00:47:50,957 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:50,959 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:50,968 - root - INFO - mu=-0.9621802102409268,sigma=0.509965915499424
# 2024-09-04 00:47:50,968 - root - INFO - y_main=0.10909875378710844,u_shaded=0.033717384171637534,l_shaded=0.35300894094602714
# 2024-09-04 00:47:50,969 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:50,988 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_32768.pth
# 2024-09-04 00:47:50,989 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:50,989 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:50,989 - root - INFO - dim=4
# 2024-09-04 00:47:55,532 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:47:55,534 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:47:55,544 - root - INFO - mu=-1.0815019531749674,sigma=0.5185663182163753
# 2024-09-04 00:47:55,545 - root - INFO - y_main=0.08288921884451433,u_shaded=0.025114915922697226,l_shaded=0.2735674139543732
# 2024-09-04 00:47:55,545 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:47:55,573 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_65536.pth
# 2024-09-04 00:47:55,573 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:47:55,574 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:47:55,574 - root - INFO - dim=4
# 2024-09-04 00:48:00,337 - root - INFO -
# predicted.shape=torch.Size([32768, 16])
# actuals.shape=torch.Size([32768, 16])
# 2024-09-04 00:48:00,338 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:48:00,351 - root - INFO - mu=-1.2014297678963952,sigma=0.5143083967861791
# 2024-09-04 00:48:00,352 - root - INFO - y_main=0.06288835460461878,u_shaded=0.019242515068360132,l_shaded=0.2055316122048552
# 2024-09-04 00:48:00,353 - root - INFO - x_raw.shape=(524288,), y_raw.shape=(524288,)
# 2024-09-04 00:48:00,403 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_4/cos_model_131072.pth
# 2024-09-04 00:48:00,406 - root - INFO - len(test_dataset)=32768
# ...
#
# train_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/train/train_dataset_262144.pt']
#
# test_lst=['/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_32.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_64.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_128.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_256.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_512.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_1024.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_2048.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_4096.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_8192.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_16384.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_32768.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_65536.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_131072.pt', '/mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/test/test_dataset_262144.pt']
# 2024-09-04 00:53:38,199 - root - INFO - idx=0
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_32.pth
# 2024-09-04 00:53:38,200 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:53:38,200 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:53:38,200 - root - INFO - dim=10
# 2024-09-04 00:53:42,905 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:53:42,933 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:53:43,000 - root - INFO - mu=-0.005354510681557917,sigma=0.22917611720573117
# 2024-09-04 00:53:43,001 - root - INFO - y_main=0.9877464769144035,u_shaded=0.5827326771060728,l_shaded=1.674255007462407
# 2024-09-04 00:53:43,002 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:53:43,040 - root - INFO - idx=1
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_64.pth
# 2024-09-04 00:53:43,041 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:53:43,041 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:53:43,042 - root - INFO - dim=10
# 2024-09-04 00:53:47,477 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:53:47,484 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:53:47,548 - root - INFO - mu=0.009336353287719685,sigma=0.2636346463775356
# 2024-09-04 00:53:47,549 - root - INFO - y_main=1.0217304892988555,u_shaded=0.5568031799604106,l_shaded=1.8748693081047123
# 2024-09-04 00:53:47,551 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:53:47,590 - root - INFO - idx=2
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_128.pth
# 2024-09-04 00:53:47,590 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:53:47,591 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:53:47,591 - root - INFO - dim=10
# 2024-09-04 00:53:52,326 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:53:52,333 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:53:52,397 - root - INFO - mu=0.026722822770437055,sigma=0.30033223117608443
# 2024-09-04 00:53:52,398 - root - INFO - y_main=1.0634640731263068,u_shaded=0.5325870369424767,l_shaded=2.1235136351103985
# 2024-09-04 00:53:52,400 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:53:52,437 - root - INFO - idx=3
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_256.pth
# 2024-09-04 00:53:52,438 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:53:52,438 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:53:52,438 - root - INFO - dim=10
# 2024-09-04 00:53:57,205 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:53:57,211 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:53:57,283 - root - INFO - mu=0.03467972628774829,sigma=0.31492558327313136
# 2024-09-04 00:53:57,283 - root - INFO - y_main=1.083127858686432,u_shaded=0.5245104473457063,l_shaded=2.236687494404508
# 2024-09-04 00:53:57,285 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:53:57,322 - root - INFO - idx=4
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_512.pth
# 2024-09-04 00:53:57,323 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:53:57,323 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:53:57,324 - root - INFO - dim=10
# 2024-09-04 00:54:02,033 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:02,040 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:02,100 - root - INFO - mu=0.0385769092764507,sigma=0.3245093719724222
# 2024-09-04 00:54:02,101 - root - INFO - y_main=1.0928911503144172,u_shaded=0.5176873314496923,l_shaded=2.3072055155200184
# 2024-09-04 00:54:02,103 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:02,150 - root - INFO - idx=5
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_1024.pth
# 2024-09-04 00:54:02,151 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:02,151 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:02,152 - root - INFO - dim=10
# 2024-09-04 00:54:07,143 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:07,150 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:07,215 - root - INFO - mu=0.04058948545179539,sigma=0.33370530942602267
# 2024-09-04 00:54:07,215 - root - INFO - y_main=1.097967500829771,u_shaded=0.509195053398164,l_shaded=2.3675262059855657
# 2024-09-04 00:54:07,217 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:07,276 - root - INFO - idx=6
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_2048.pth
# 2024-09-04 00:54:07,276 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:07,277 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:07,277 - root - INFO - dim=10
# 2024-09-04 00:54:12,162 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:12,168 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:12,230 - root - INFO - mu=0.029844791680329677,sigma=0.3315161024579924
# 2024-09-04 00:54:12,230 - root - INFO - y_main=1.0711364336986045,u_shaded=0.49926220356931533,l_shaded=2.2980575164594335
# 2024-09-04 00:54:12,232 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:12,272 - root - INFO - idx=7
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_4096.pth
# 2024-09-04 00:54:12,273 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:12,273 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:12,274 - root - INFO - dim=10
# 2024-09-04 00:54:17,140 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:17,146 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:17,208 - root - INFO - mu=0.004582135868160484,sigma=0.30989589462732314
# 2024-09-04 00:54:17,209 - root - INFO - y_main=1.010606613255072,u_shaded=0.4950923789892723,l_shaded=2.062899309498393
# 2024-09-04 00:54:17,217 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:17,283 - root - INFO - idx=8
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_8192.pth
# 2024-09-04 00:54:17,283 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:17,284 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:17,284 - root - INFO - dim=10
# 2024-09-04 00:54:21,849 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:21,856 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:21,919 - root - INFO - mu=-0.021151900495805766,sigma=0.28571495426117804
# 2024-09-04 00:54:21,920 - root - INFO - y_main=0.9524629686734871,u_shaded=0.4933250234966991,l_shaded=1.8389209212704414
# 2024-09-04 00:54:21,922 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:21,970 - root - INFO - idx=9
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_16384.pth
# 2024-09-04 00:54:21,971 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:21,971 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:21,972 - root - INFO - dim=10
# 2024-09-04 00:54:26,599 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:26,627 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:26,691 - root - INFO - mu=-0.047856262735804275,sigma=0.2618485966466449
# 2024-09-04 00:54:26,691 - root - INFO - y_main=0.8956611510365514,u_shaded=0.4901117795111674,l_shaded=1.6367876288879146
# 2024-09-04 00:54:26,693 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:26,786 - root - INFO - idx=10
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_32768.pth
# 2024-09-04 00:54:26,787 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:26,787 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:26,788 - root - INFO - dim=10
# 2024-09-04 00:54:31,530 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:31,537 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:31,600 - root - INFO - mu=-0.07810541021348529,sigma=0.2645829962566215
# 2024-09-04 00:54:31,601 - root - INFO - y_main=0.8354002286317235,u_shaded=0.45426742328635367,l_shaded=1.5363055024925465
# 2024-09-04 00:54:31,603 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:31,725 - root - INFO - idx=11
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_65536.pth
# 2024-09-04 00:54:31,726 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:31,727 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:31,727 - root - INFO - dim=10
# 2024-09-04 00:54:36,167 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:36,174 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:36,242 - root - INFO - mu=-0.08858520836518821,sigma=0.2681448218900318
# 2024-09-04 00:54:36,242 - root - INFO - y_main=0.8154827741141604,u_shaded=0.4398149318911766,l_shaded=1.5120272338581509
# 2024-09-04 00:54:36,245 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:36,512 - root - INFO - idx=12
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_131072.pth
# 2024-09-04 00:54:36,512 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:36,513 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:36,513 - root - INFO - dim=10
# 2024-09-04 00:54:41,130 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:41,137 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:41,199 - root - INFO - mu=-0.09066638930836195,sigma=0.261423054336858
# 2024-09-04 00:54:41,199 - root - INFO - y_main=0.8115842507086221,u_shaded=0.4445397043754264,l_shaded=1.4816876637008127
# 2024-09-04 00:54:41,201 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
# 2024-09-04 00:54:41,603 - root - INFO - idx=13
# Loaded model: /mnt/wd_2tb/thesis_transformers/experiments/cos/20240903194208/dim_10/cos_model_262144.pth
# 2024-09-04 00:54:41,604 - root - INFO - len(test_dataset)=32768
# 2024-09-04 00:54:41,604 - root - INFO - Starting to predict values in the test_dataset
# 2024-09-04 00:54:41,605 - root - INFO - dim=10
# 2024-09-04 00:54:46,176 - root - INFO -
# predicted.shape=torch.Size([32768, 100])
# actuals.shape=torch.Size([32768, 100])
# 2024-09-04 00:54:46,183 - root - INFO - np_predicted.dtype=dtype('float64'),np_actuals.dtype=dtype('float64')
# 2024-09-04 00:54:46,247 - root - INFO - mu=-0.09430770455681838,sigma=0.26837256086647554
# 2024-09-04 00:54:46,248 - root - INFO - y_main=0.8048080198475296,u_shaded=0.43383015357607546,l_shaded=1.4930173559208801
# 2024-09-04 00:54:46,249 - root - INFO - x_raw.shape=(3276800,), y_raw.shape=(3276800,)
